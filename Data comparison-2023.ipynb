# %% [markdown]
# # IMPORT DATA

# %%
import pandas as pd

# %%
imo=pd.read_csv('IMO_DCS_2023.csv')
imo
# Out:
# C:\Users\akshaya\AppData\Local\Temp\ipykernel_191184\3651507769.py:1: DtypeWarning: Columns (18,20,64,66,68,75) have mixed types. Specify dtype option on import or set low_memory=False.
#   imo=pd.read_csv('IMO_DCS_2023.csv')
#        Source_System      IMO    Date_UTC Time_UTC      Event   Event_Id  \
# 0           OVDAdmin  7602120  2023-01-01    10:00  PORT NOON        NaN
# 1           OVDAdmin  7602120  2023-01-02    10:00  PORT NOON        NaN
# 2           OVDAdmin  7602120  2023-01-03    10:00  PORT NOON        NaN
# 3           OVDAdmin  7602120  2023-01-04    10:00  PORT NOON        NaN
# 4           OVDAdmin  7602120  2023-01-05    10:00  PORT NOON        NaN
# ...              ...      ...         ...      ...        ...        ...
# 363902      OVDAdmin  9962550  2023-12-31     5:12  DEPARTURE  5191171.0
# 363903      OVDAdmin  9962550  2023-12-31     5:13  DEPARTURE  5191171.0
# 363904        OVDAPI  9962550  2023-12-31     7:30       COSP  5191159.0
# 363905        OVDAPI  9962550  2023-12-31    14:36       EOSP  5191170.0
# 363906        OVDAPI  9962550  2023-12-31    15:00      DELAY  5191169.0
#
#         Sort_Number  Time_Since_Previous_Report  Distance  \
# 0               NaN                        24.0       0.0
# 1               NaN                        24.0       0.0
# 2               NaN                        24.0       0.0
# 3               NaN                        24.0       0.0
# 4               NaN                        24.0       0.0
# ...             ...                         ...       ...
# 363902          NaN                         1.2       0.0
# 363903          NaN                         0.0       0.0
# 363904          NaN                         2.3      13.0
# 363905          NaN                         7.1      60.0
# 363906          NaN                         0.4       1.0
#
#        Latitude_North_South  ...  ME_Consumption_BDN_2  AE_Fuel_BDN  \
# 0                         N  ...                   NaN          NaN
# 1                         N  ...                   NaN          NaN
# 2                         N  ...                   NaN          NaN
# 3                         N  ...                   NaN          NaN
# 4                         N  ...                   NaN          NaN
# ...                     ...  ...                   ...          ...
# 363902                    S  ...                   NaN          NaN
# 363903                    S  ...                   NaN          NaN
# 363904                    N  ...                   NaN          NaN
# 363905                    N  ...                   NaN          NaN
# 363906                    N  ...                   NaN          NaN
#
#        AE_Consumption  Reefer_SFOC  Reefer_Fuel_Type Wind_Force_Kn  \
# 0                 NaN          NaN               NaN           NaN
# 1                 NaN          NaN               NaN           NaN
# 2                 NaN          NaN               NaN           NaN
# 3                 NaN          NaN               NaN           NaN
# 4                 NaN          NaN               NaN           NaN
# ...               ...          ...               ...           ...
# 363902            NaN        158.5               MGO           NaN
# 363903            NaN        158.5               MGO           NaN
# 363904            NaN        158.5               MGO          15.0
# 363905            NaN        158.5               MGO          15.0
# 363906            NaN        158.5               MGO           NaN
#
#        Wind_Force_Bft Wind_Dir_Degree Remarks Reefer_Fuel_BDN
# 0                 1.0             NaN     NaN             NaN
# 1                 1.0             NaN     NaN             NaN
# 2                 1.0             NaN     NaN             NaN
# 3                 1.0             NaN     NaN             NaN
# 4                 1.0             NaN     NaN             NaN
# ...               ...             ...     ...             ...
# 363902            NaN             NaN     NaN             NaN
# 363903            NaN             NaN     NaN             NaN
# 363904            4.0           330.0     NaN             NaN
# 363905            4.0           330.0     NaN             NaN
# 363906            NaN             NaN     NaN             NaN
#
# [363907 rows x 77 columns]

# %%
lim=pd.read_csv('Limmasol_2023.csv')
lim
# Out:
# C:\Users\akshaya\AppData\Local\Temp\ipykernel_191184\1334575195.py:1: DtypeWarning: Columns (156,157,158) have mixed types. Specify dtype option on import or set low_memory=False.
#   lim=pd.read_csv('Limmasol_2023.csv')
#         MessagesId  ImoNumber                vName   MessageType  \
# 0          4504378    9289051      MSC GIANNINA II         Delay
# 1          4503870    9309289     MSC BELMONTE III         Delay
# 2          4504253    9456965         MSC ODESSA V      Berthing
# 3          4505330    9194866         MSC CHERYL 3          COSP
# 4          4504470    9239903       MSC PAMIRA III  COSP Transit
# ...            ...        ...                  ...           ...
# 382729     5190496    9227285           MSC YANG R          EOSP
# 382730     5189071    9252230            MSC REN V          COSP
# 382731     5188828    9936628  MSC CLAUDE GIRARDET      Berthing
# 382732     5189670    9930935    MSC BIANCA SILVIA         Delay
# 382733     5189109    9327683       MSC MAKALU III          COSP
#
#                         DateTimeLt       DateTimeUtc Latitude Longitude  \
# 0       2023-01-01 10:18:00 +10:00   2023-01-01 0:18    4304N    13153E
# 1       2023-01-01 11:24:00 +11:00   2023-01-01 0:24    3406S    15130E
# 2       2022-12-31 18:24:00 -06:00   2023-01-01 0:24      NaN       NaN
# 3       2023-01-01 08:30:00 +08:00   2023-01-01 0:30    0113N    10339E
# 4       2023-01-01 03:30:00 +03:00   2023-01-01 0:30    4112N    02906E
# ...                            ...               ...      ...       ...
# 382729  2024-01-01 08:24:00 +09:00  2023-12-31 23:24    3452N    12851E
# 382730  2024-01-01 06:30:00 +07:00  2023-12-31 23:30      NaN       NaN
# 382731  2024-01-01 07:42:00 +08:00  2023-12-31 23:42      NaN       NaN
# 382732  2023-12-31 20:48:00 -03:00  2023-12-31 23:48    3641S    07303W
# 382733  2024-01-01 07:54:00 +08:00  2023-12-31 23:54    2226N    11428E
#
#         CargoMT  CargoTEU  ...  Rob Adjustment ULS  Rob Adjustment Dist  \
# 0       12186.1     902.0  ...                 NaN                  NaN
# 1       16405.0    1738.0  ...                 NaN                  NaN
# 2        8998.5    2627.0  ...                 NaN                  NaN
# 3        7780.0    1145.0  ...                 NaN                  NaN
# 4       13141.0     489.0  ...                 NaN                  NaN
# ...         ...       ...  ...                 ...                  ...
# 382729  13379.0    1528.0  ...                 NaN                  NaN
# 382730  26635.7    2449.0  ...                 NaN                  NaN
# 382731      0.0       0.0  ...                 NaN                  NaN
# 382732  75023.5    5836.0  ...                 NaN                  NaN
# 382733   5084.8     831.0  ...                 NaN                  NaN
#
#         Rob Adjustment LNG  Drydock  Rob Ajustment VLS  Rob Ajustment ULS  \
# 0                      NaN      NaN                NaN                NaN
# 1                      NaN      NaN                NaN                NaN
# 2                      NaN      NaN                NaN                NaN
# 3                      NaN      NaN                NaN                NaN
# 4                      NaN      NaN                NaN                NaN
# ...                    ...      ...                ...                ...
# 382729                 NaN      NaN                NaN                NaN
# 382730                 NaN      NaN                NaN                NaN
# 382731                 NaN      NaN                NaN                NaN
# 382732                 NaN      NaN                NaN                NaN
# 382733                 NaN      NaN                NaN                NaN
#
#         Rob Ajustment Dist  Rob Ajustment LNG  DryDock  Drydock2
# 0                      NaN                NaN      NaN       NaN
# 1                      NaN                NaN      NaN       NaN
# 2                      NaN                NaN      NaN       NaN
# 3                      NaN                NaN      NaN       NaN
# 4                      NaN                NaN      NaN       NaN
# ...                    ...                ...      ...       ...
# 382729                 NaN                NaN      NaN       NaN
# 382730                 NaN                NaN      NaN       NaN
# 382731                 NaN                NaN      NaN       NaN
# 382732                 NaN                NaN      NaN       NaN
# 382733                 NaN                NaN      NaN       NaN
#
# [382734 rows x 172 columns]

# %%
imo.shape
# Out:
# (363907, 77)

# %%
lim.shape
# Out:
# (382734, 172)

# %% [markdown]
# # IMO CHECKING

# %%
imo_unique_count= len(set(imo["IMO"]))
imo_unique_count
# Out:
# 576

# %%
lim_unique_count= len(set(lim["ImoNumber"]))
lim_unique_count
# Out:
# 552

# %%
imo_unique_missing=set(imo["IMO"])
imo_unique_missing
# Out:
# {7602120,
#  7826790,
#  8201624,
#  8201636,
#  8201648,
#  8413875,
#  8413887,
#  8420892,
#  8420907,
#  8505836,
#  8509375,
#  8509387,
#  8512891,
#  8512906,
#  8521397,
#  8521402,
#  8608200,
#  8616520,
#  8618293,
#  8712520,
#  8714205,
#  8715857,
#  8715869,
#  8715871,
#  8913411,
#  8913423,
#  8913447,
#  8917778,
#  8918057,
#  8918954,
#  8918966,
#  8918978,
#  8918980,
#  9000742,
#  9004231,
#  9008574,
#  9008603,
#  9036002,
#  9038907,
#  9039250,
#  9043756,
#  9051478,
#  9051492,
#  9051507,
#  9057173,
#  9060649,
#  9062984,
#  9062996,
#  9064748,
#  9064750,
#  9067544,
#  9074042,
#  9084607,
#  9102710,
#  9102722,
#  9102746,
#  9103685,
#  9106479,
#  9106493,
#  9108398,
#  9110377,
#  9110389,
#  9110391,
#  9110975,
#  9113446,
#  9116369,
#  9120841,
#  9120853,
#  9123154,
#  9123166,
#  9123221,
#  9124366,
#  9124512,
#  9127021,
#  9127540,
#  9134490,
#  9135638,
#  9138783,
#  9139086,
#  9139505,
#  9141285,
#  9141297,
#  9141780,
#  9143879,
#  9144134,
#  9146467,
#  9146479,
#  9147071,
#  9147215,
#  9147227,
#  9148025,
#  9149328,
#  9150080,
#  9152856,
#  9153850,
#  9154191,
#  9154206,
#  9154220,
#  9155107,
#  9158525,
#  9160920,
#  9160982,
#  9161297,
#  9162277,
#  9162631,
#  9162643,
#  9163192,
#  9163207,
#  9166651,
#  9166778,
#  9166780,
#  9168831,
#  9168843,
#  9169029,
#  9169031,
#  9169043,
#  9169055,
#  9169067,
#  9169122,
#  9180190,
#  9180205,
#  9180968,
#  9440306,
#  9444285,
#  9449687,
#  9449869,
#  9450296,
#  9450325,
#  9450351,
#  9453298,
#  9456965,
#  9463035,
#  9463047,
#  9463059,
#  9463205,
#  9463281,
#  9465241,
#  9465253,
#  9465265,
#  9465277,
#  9465306,
#  9465318,
#  9466960,
#  9467445,
#  9471226,
#  9471238,
#  9477309,
#  9477610,
#  9491616,
#  9499010,
#  9502908,
#  9502960,
#  9503732,
#  9540065,
#  9540077,
#  9605243,
#  9618264,
#  9618276,
#  9618288,
#  9618290,
#  9618305,
#  9618317,
#  9619452,
#  9622007,
#  9625932,
#  9625944,
#  9625970,
#  9631876,
#  9695016,
#  9695028,
#  9702065,
#  9702077,
#  9702089,
#  9702091,
#  9702106,
#  9702261,
#  9702273,
#  9704960,
#  9704972,
#  9704984,
#  9704996,
#  9705005,
#  9706310,
#  9710426,
#  9710438,
#  9720196,
#  9720201,
#  9720287,
#  9720457,
#  9720471,
#  9720483,
#  9720495,
#  9720500,
#  9720512,
#  9720524,
#  9724049,
#  9735206,
#  9735218,
#  9745653,
#  9756729,
#  9756731,
#  9770737,
#  9770749,
#  9770751,
#  9770763,
#  9778076,
#  9778088,
#  9778090,
#  9778105,
#  9778117,
#  9785445,
#  9785457,
#  9785469,
#  9785471,
#  9785483,
#  9793947,
#  9839260,
#  9839272,
#  9839284,
#  9839296,
#  9839301,
#  9842061,
#  9842073,
#  9842085,
#  9842097,
#  9842102,
#  9857157,
#  9857169,
#  9857171,
#  9857183,
#  9896983,
#  9896995,
#  9908047,
#  9908059,
#  9927251,
#  9927263,
#  9927275,
#  9927287,
#  9927299,
#  9929429,
#  9929431,
#  9930038,
#  9930052,
#  9930064,
#  9930935,
#  9930947,
#  9930959,
#  9931288,
#  9931290,
#  9932036,
#  9932048,
#  9932050,
#  9932062,
#  9932892,
#  9932907,
#  9934735,
#  9934747,
#  9936616,
#  9936628,
#  9936630,
#  9936642,
#  9946714,
#  9946843,
#  9946855,
#  9947110,
#  9947122,
#  9947134}

# %%
missing_lim = lim_unique_missing - imo_unique_missing
missing_lim
# Out:
# {9618264, 9618290, 9618305, 9618317}

# %%
missing_imo = imo_unique_missing - lim_unique_missing
missing_imo
#imp
# Out:
# {9106479,
#  9106493,
#  9141780,
#  9147215,
#  9148025,
#  9158525,
#  9160920,
#  9219379,
#  9222273,
#  9222285,
#  9225794,
#  9265598,
#  9286774,
#  9320398,
#  9321897,
#  9326835,
#  9334519,
#  9360764,
#  9362449,
#  9449821,
#  9605152,
#  9605231,
#  9930961,
#  9932919,
#  9946867,
#  9957347,
#  9962548,
#  9962550}

# %%
print("Missing imo dcs", len(missing_imo))
print("Missing imo limmasol", len(missing_lim))
# Out:
# Missing imo dcs 28
# Missing imo limmasol 4

# %%
imo_df=imo.copy()
lim_df=lim.copy()

# %%
imo_set ={9106479,
 9106493,
 9141780,
 9147215,
 9148025,
 9158525,
 9160920,
 9219379,
 9222273,
 9222285,
 9225794,
 9265598,
 9286774,
 9320398,
 9321897,
 9326835,
 9334519,
 9360764,
 9362449,
 9449821,
 9605152,
 9605231,
 9930961,
 9932919,
 9946867,
 9957347,
 9962548,
 9962550}

imolst = list(imo_set)

# Create a generator expression to format each IMO number with single quotes
formatted_imolst = ("{}".format(imo) for imo in imolst)

# Convert the generator object to a list
formatted_imolst_list = list(formatted_imolst)

print(formatted_imolst_list)
# Out:
# ['9222273', '9225794', '9222285', '9320398', '9147215', '9362449', '9930961', '9148025', '9141780', '9932919', '9160920', '9449821', '9605152', '9957347', '9321897', '9158525', '9106479', '9605231', '9219379', '9962548', '9326835', '9962550', '9334519', '9946867', '9286774', '9360764', '9106493', '9265598']

# %%
#Comparion between imo dcs with noon data

# %%
imo_lst=['9618264', '9618290', '9618305', '9618317']
lim_df = lim_df[~lim_df['ImoNumber'].isin(imo_lst)]
lim_df['ImoNumber'] = lim_df['ImoNumber'].astype(str)
lim_df = lim_df[~lim_df['ImoNumber'].isin(imo_lst)]

# %%
imo_lst=['9222273', '9225794', '9222285', '9320398', '9147215', '9362449', '9930961', '9148025', '9141780', '9932919', '9160920', '9449821', '9605152', '9957347', '9321897', '9158525', '9106479', '9605231', '9219379', '9962548', '9326835', '9962550', '9334519', '9946867', '9286774', '9360764', '9106493', '9265598']
imo_df = imo_df[~imo_df['IMO'].isin(imo_lst)]
imo_df['IMO'] = imo_df['IMO'].astype(str)
imo_df = imo_df[~imo_df['IMO'].isin(imo_lst)]

# %%
print('imo dcs',imo_df['IMO'].nunique())
print('Limmasol',lim_df['ImoNumber'].nunique())
# Out:
# imo dcs 548
# Limmasol 548

# %% [markdown]
# # REPORT TYPE CHCEKING

# %%
unique_events_count = imo_df['Event'].nunique()

print("Number of unique events:", unique_events_count)
# Out:
# Number of unique events: 45

# %%
unique_event_count = imo_df['Event'].unique()

unique_event_count
# Out:
# array(['PORT NOON', 'DEPARTURE', 'BOSP', 'NOON REPORT', 'EOSP', 'ARRIVAL',
#        'duplicate', 'DELAY ARRIVAL', 'Noon (Position) - Port',
#        'Begin of sea passage', 'End of sea passage',
#        'Noon (Position) - Sea passage', 'DELAY', 'cancelled', 'COSP',
#        'NOON', 'COSP TRANSIT', 'DELAY DEPARTURE', 'ignore', 'Arrival',
#        'Departure', 'Duplicate', 'duplciate', 'PORTNOON', 'wrong entry',
#        'Cancelled', 'At Anchor', 'Noon', nan, 'Port Noon',
#        'canal passage', 'Begin Of Sea Passage', 'Noon At Sea',
#        'End Of Sea Passage', 'Begin Fuel Change Over',
#        'End Fuel Change Over', 'Noon In Port', 'Begin Waiting/Drifting',
#        'End Waiting/Drifting', 'Destination Changed', 'Drop Anchor',
#        'Heave Anchor', 'Noon Maneuvering', 'noon at port', 'SOSP', 'noon'],
#       dtype=object)

# %%
imo_df
# Out:
#        Source_System      IMO    Date_UTC Time_UTC      Event   Event_Id  \
# 0           OVDAdmin  7602120  2023-01-01    10:00  PORT NOON        NaN
# 1           OVDAdmin  7602120  2023-01-02    10:00  PORT NOON        NaN
# 2           OVDAdmin  7602120  2023-01-03    10:00  PORT NOON        NaN
# 3           OVDAdmin  7602120  2023-01-04    10:00  PORT NOON        NaN
# 4           OVDAdmin  7602120  2023-01-05    10:00  PORT NOON        NaN
# ...              ...      ...         ...      ...        ...        ...
# 363832        OVDAPI  9947134  2023-12-27     9:00       NOON  5181079.0
# 363833        OVDAPI  9947134  2023-12-28    10:00       NOON  5183009.0
# 363834        OVDAPI  9947134  2023-12-29    10:00       NOON  5184824.0
# 363835        OVDAPI  9947134  2023-12-30    10:00       NOON  5186493.0
# 363836        OVDAPI  9947134  2023-12-31    11:00       NOON  5188287.0
#
#         Sort_Number  Time_Since_Previous_Report  Distance  \
# 0               NaN                        24.0       0.0
# 1               NaN                        24.0       0.0
# 2               NaN                        24.0       0.0
# 3               NaN                        24.0       0.0
# 4               NaN                        24.0       0.0
# ...             ...                         ...       ...
# 363832          NaN                        24.0     279.0
# 363833          NaN                        25.0     503.0
# 363834          NaN                        24.0     457.0
# 363835          NaN                        24.0     458.0
# 363836          NaN                        25.0     475.0
#
#        Latitude_North_South  ...  ME_Consumption_BDN_2  AE_Fuel_BDN  \
# 0                         N  ...                   NaN          NaN
# 1                         N  ...                   NaN          NaN
# 2                         N  ...                   NaN          NaN
# 3                         N  ...                   NaN          NaN
# 4                         N  ...                   NaN          NaN
# ...                     ...  ...                   ...          ...
# 363832                    S  ...                   NaN          NaN
# 363833                    S  ...                   NaN          NaN
# 363834                    S  ...                   NaN          NaN
# 363835                    S  ...                   NaN          NaN
# 363836                    S  ...                   NaN          NaN
#
#        AE_Consumption  Reefer_SFOC  Reefer_Fuel_Type Wind_Force_Kn  \
# 0                 NaN          NaN               NaN           NaN
# 1                 NaN          NaN               NaN           NaN
# 2                 NaN          NaN               NaN           NaN
# 3                 NaN          NaN               NaN           NaN
# 4                 NaN          NaN               NaN           NaN
# ...               ...          ...               ...           ...
# 363832            NaN        153.8               HFO          20.0
# 363833            NaN        153.8               HFO          12.0
# 363834            NaN        153.8               HFO          20.0
# 363835            NaN        153.8               HFO          11.0
# 363836            NaN        153.8               HFO          16.0
#
#        Wind_Force_Bft Wind_Dir_Degree Remarks Reefer_Fuel_BDN
# 0                 1.0             NaN     NaN             NaN
# 1                 1.0             NaN     NaN             NaN
# 2                 1.0             NaN     NaN             NaN
# 3                 1.0             NaN     NaN             NaN
# 4                 1.0             NaN     NaN             NaN
# ...               ...             ...     ...             ...
# 363832            5.0           100.0     NaN             NaN
# 363833            4.0            90.0     NaN             NaN
# 363834            5.0            20.0     NaN             NaN
# 363835            4.0            30.0     NaN             NaN
# 363836            4.0           350.0     NaN             NaN
#
# [351272 rows x 77 columns]

# %%
lim_df.columns.to_list()
# Out:
# ['MessagesId',
#  'ImoNumber',
#  'vName',
#  'MessageType',
#  'DateTimeLt',
#  'DateTimeUtc',
#  'Latitude',
#  'Longitude',
#  'CargoMT',
#  'CargoTEU',
#  'DraftAft',
#  'DraftFwd',
#  'Speed by gps',
#  'Speed by log',
#  'FOC_AE_DIS',
#  'FOC_AE_DIS_ULS',
#  'FOC_AE_DIS_VLS',
#  'FOC_AE_LNG',
#  'FOC_AE_RES_HS',
#  'FOC_AE_RES_ULS',
#  'FOC_AE_RES_VLS',
#  'FOC_BLR_DIS',
#  'FOC_BLR_DIS_ULS',
#  'FOC_BLR_DIS_VLS',
#  'FOC_BLR_LNG',
#  'FOC_BLR_RES_HS',
#  'FOC_BLR_RES_ULS',
#  'FOC_BLR_RES_VLS',
#  'FOC_ME_DIS',
#  'FOC_ME_DIS_ULS',
#  'FOC_ME_DIS_VLS',
#  'FOC_ME_LNG',
#  'FOC_ME_RES_HS',
#  'FOC_ME_RES_ULS',
#  'FOC_ME_RES_VLS',
#  'Hours_AE_1',
#  'Hours_AE_2',
#  'Hours_AE_3',
#  'Hours_AE_4',
#  'Hours_AE_5',
#  'Hours_ME',
#  'Hours_SG',
#  'Hours_TG',
#  'Power_AE_1',
#  'Power_AE_2',
#  'Power_AE_3',
#  'Power_AE_4',
#  'Power_AE_5',
#  'Power_ME',
#  'Power_SG',
#  'Power_TG',
#  'ROB_DIS',
#  'ROB_DIS_ULS',
#  'ROB_DIS_VLS',
#  'ROB_LNG',
#  'ROB_RES_HS',
#  'ROB_RES_ULS',
#  'ROB_RES_VLS',
#  'Port Code',
#  'Port Name',
#  'ETA Date/Time',
#  'Eta date/time',
#  'Sludge rob',
#  'Sludge min discharge request',
#  'Max Residual HS capacity',
#  'Max Lng capacity',
#  'Min Lng request',
#  'Tanktainer number',
#  'Port bunkering',
#  'Wind direction',
#  'Miles by gps',
#  'STEAMING TIME M/E RESIDUAL HS',
#  'RPM',
#  'Slip',
#  'Displacement',
#  'ETA Port Code',
#  'ETA Port Name',
#  'Wind speed',
#  'Course at Sea',
#  'Number of Tanktainer',
#  'Wave height',
#  'Sea state',
#  'Ambient temp',
#  'Sw temp',
#  'Miles speed log',
#  'Requested speed',
#  'Time change',
#  'Time sea',
#  'kwhr total',
#  'Scavenge pressure',
#  'Reefers positive plugged',
#  'Reefers negative plugged',
#  'Me total revs counter',
#  'Rob fresh water',
#  'SEA DIRECTION',
#  'Eca miles',
#  'Eca time',
#  'Egcs running time',
#  'So2/co2 ratio',
#  'Rob tot Sludge',
#  'Ballast',
#  'Egcs closed loop running time',
#  'Egcs open loop running time',
#  'Steaming time m/e lng',
#  'Reefer power consumption',
#  'Pilot date/time',
#  'PIER date/time',
#  'Time manoeuvring',
#  'Estimated departure date/time',
#  'Manoeuvring miles by gps',
#  'Manoeuvring miles by speed log',
#  'Kwhr total',
#  'Hold ventilation off',
#  'ETB Date/Time',
#  'Steaming time m/e residual hs',
#  'Steaming time m/e residual uls',
#  'Steaming time m/e residual vls',
#  'Steaming time m/e distillate vls',
#  'Steaming time m/e distillate uls',
#  'Rpm',
#  'Type of delay',
#  'Reason',
#  'Time hrs. anchor',
#  'Time hrs. drift',
#  'TEU Full',
#  'TEU Empty',
#  'Fresh water supply',
#  'Tanktainer distillates transfd',
#  'Hold Ventilation On/Off',
#  'Bilge removed',
#  'Tot sludge removed',
#  'Garbage cat a - plastic removed',
#  'Garbage cat b - organic removed',
#  'Garbage cat c - domestic removed',
#  'Garbage cat e - ashes removed',
#  'Rob garbage cat a - plastic',
#  'Rob garbage cat b - organic',
#  'Rob garbage cat c - domestic',
#  'Rob garbage cat e - ashes',
#  'Egcs wet waste removed',
#  'Egcs dry waste removed',
#  'Shift berth hours',
#  'Oil Cylinder',
#  'ROB fresh water',
#  'Product Name',
#  'Physical supplier name',
#  'Volume',
#  'Quantity',
#  'Density at 15°C',
#  'Viscosity at 40°C or 50°C',
#  'Sulfur content',
#  'Bunker Order',
#  'Bdn number',
#  'Rob actual sludge',
#  'Rob actual bilge',
#  'Qty sludge disposed',
#  'Tanktainer min request',
#  'Comments',
#  'Template version',
#  'TANKTAINER ROB',
#  'Rob Ajustment HS',
#  'Rob Adjustment VLS',
#  'Rob Adjustment ULS',
#  'Rob Adjustment Dist',
#  'Rob Adjustment LNG',
#  'Drydock',
#  'Rob Ajustment VLS',
#  'Rob Ajustment ULS',
#  'Rob Ajustment Dist',
#  'Rob Ajustment LNG',
#  'DryDock',
#  'Drydock2']

# %%
#DUPLICATES

# %%
columns_of_interest = ['MessagesId','ImoNumber', 'DateTimeUtc','Miles by gps','Rpm','Kwhr total']
lim_df = lim_df[columns_of_interest]
duplicates = lim_df.duplicated()
duplicate_rows = lim_df[duplicates]
print(duplicate_rows)
duplicate_rows.to_csv('L.csv', index=False)
imo_df.drop_duplicates(inplace=True)

# %%
columns_of_interest = ['IMO','Date_UTC', 'Time_UTC','Distance',"ME_Consumption_HFO", "ME_Consumption_LFO", "ME_Consumption_MGO", "ME_Consumption_MDO", "ME_Consumption_LNG", "AE_Consumption_HFO", "AE_Consumption_LFO", "AE_Consumption_MGO", "AE_Consumption_MDO", "AE_Consumption_LNG", "Boiler_Consumption_HFO", "Boiler_Consumption_LFO", "Boiler_Consumption_MGO", "Boiler_Consumption_MDO", "Boiler_Consumption_LNG",]
duplicates = imo_df.duplicated()
duplicate_rows = imo_df[duplicates]
print(duplicate_rows)
duplicate_rows.to_csv('D.csv', index=False)
imo_df.drop_duplicates(inplace=True)

# %%
imo_df.shape

# %% [markdown]
# # Days

# %%
imo_df['Date_UTC'] = pd.to_datetime(imo_df['Date_UTC'])

result = imo_df.groupby('IMO')['Date_UTC'].agg(['min', 'max']).reset_index()

# Calculate number of days
result['min'] = pd.to_datetime(result['min'])
result['max'] = pd.to_datetime(result['max'])
result['Days Count'] = (result['max'] - result['min']).dt.days + 1

missing_dates = []

for _, row in result.iterrows():
    imo_no = row['IMO']
    date_range = pd.date_range(start=row['min'], end=row['max'], freq='D')
    actual_dates = set(imo_df[imo_df['IMO'] == imo_no]['Date_UTC'])
    missing = list(set(date_range) - actual_dates)
    missing_str = [date.strftime('%Y-%m-%d') for date in missing]  # Convert datetime.date objects to string
    missing_dates.append([imo_no, missing_str, len(missing)])


missing_dates_imodcs = pd.DataFrame(missing_dates, columns=['imo', 'Missing Dates', 'Count'])

print(missing_dates_imodcs)

# %%
lim_df['DateTimeUtc'] = pd.to_datetime(lim_df['DateTimeUtc'])

result = lim_df.groupby('ImoNumber')['DateTimeUtc'].agg(['min', 'max']).reset_index()

# Calculate number of days
result['min'] = pd.to_datetime(result['min'])
result['max'] = pd.to_datetime(result['max'])
result['Days Count'] = (result['max'] - result['min']).dt.days + 1

missing_dates = []

for _, row in result.iterrows():
    imo_no = row['ImoNumber']
    date_range = pd.date_range(start=row['min'], end=row['max'], freq='D').date
    actual_dates = set(lim_df[lim_df['ImoNumber'] == imo_no]['DateTimeUtc'].dt.date)
    missing = list(set(date_range) - actual_dates)
    missing_str = [date.strftime('%Y-%m-%d') for date in missing]  # Convert datetime.date objects to string
    missing_dates.append([imo_no, missing_str, len(missing)])


missing_dates_lim = pd.DataFrame(missing_dates, columns=['imo', 'Missing Dates', 'Count'])

missing_dates_lim

# %%
imo_df['Date_UTC']= pd.to_datetime(imo_df['Date_UTC']).dt.date
imo_df['Date_UTC']=imo_df['Date_UTC'].astype(str)

# %%
lim_df['DateTimeUtc']= pd.to_datetime(lim_df['DateTimeUtc']).dt.date
lim_df['DateTimeUtc']=lim_df['DateTimeUtc'].astype(str)

# %%
# Iterate through each row of missing_dates_imo
for _, row in missing_dates_imodcs.iterrows():
    imo_no = row['imo']
    missing_dates = row['Missing Dates']
    
    # Convert missing_dates to datetime objects
    missing_dates = pd.to_datetime(missing_dates)
    
    # Filter out rows with the specified IMO and missing dates
    lim_df = lim_df[~((lim_df['ImoNumber'] == imo_no) & lim_df['DateTimeUtc'].isin(missing_dates))]

# %%
# Iterate through each row of missing_dates_imo
for _, row in missing_dates_lim.iterrows():
    imo_no = row['imo']
    missing_dates = row['Missing Dates']
    
    # Convert missing_dates to datetime objects
    missing_dates = pd.to_datetime(missing_dates)
    
    # Filter out rows with the specified IMO and missing dates
    imo_df = imo_df[~((imo_df['IMO'] == imo_no) & imo_df['Date_UTC'].isin(missing_dates))]

# %%
imo_df.shape

# %%
lim_df.shape

# %% [markdown]
# # Fuel and Distance

# %%
imo_df['MGO_MDO']=imo_df[['ME_Consumption_MGO','ME_Consumption_MDO','AE_Consumption_MGO','AE_Consumption_MDO','Boiler_Consumption_MGO','Boiler_Consumption_MDO']].sum(axis=1)

# %%
imo_df['Total_ME']=imo_df[['ME_Consumption_HFO','ME_Consumption_LFO','ME_Consumption_MGO','ME_Consumption_MDO']].sum(axis=1)
imo_df['Total_AE']=imo_df[['AE_Consumption_HFO','AE_Consumption_LFO','AE_Consumption_MGO','AE_Consumption_MDO']].sum(axis=1)
imo_df['Total_Boiler']=imo_df[['Boiler_Consumption_HFO','Boiler_Consumption_LFO','Boiler_Consumption_MGO','Boiler_Consumption_MDO']].sum(axis=1)

# %%
fuel_imodcs=imo_df[['IMO','Distance','Date_UTC','ME_Consumption_HFO', 'ME_Consumption_LFO','AE_Consumption_HFO','AE_Consumption_LFO',
                    'Boiler_Consumption_HFO','Boiler_Consumption_LFO','MGO_MDO','Total_ME','Total_AE','Total_Boiler'
]]

# %%
fuel_imodcs

# %%
import pandas as pd

# Assuming 'fuel_imodcs' is your DataFrame containing fuel data
fuel_imodcs['Date_UTC'] = pd.to_datetime(fuel_imodcs['Date_UTC'])

# Extracting the month from 'Date_UTC'
fuel_imodcs['month'] = fuel_imodcs['Date_UTC'].dt.month

# Grouping by 'imo' and performing aggregations
grouped_df = fuel_imodcs.groupby('IMO').agg({
    'Date_UTC': 'first',  # Assuming you want the first date in each group
    'Distance': 'sum',
    'ME_Consumption_HFO': 'sum',
    'ME_Consumption_LFO': 'sum',
    'AE_Consumption_HFO': 'sum',
    'AE_Consumption_LFO': 'sum',
    'Boiler_Consumption_HFO': 'sum',
    'Boiler_Consumption_LFO': 'sum',
    'MGO_MDO': 'sum',
    'Total_ME': 'sum',
    'Total_AE': 'sum',
    'Total_Boiler': 'sum'
}).reset_index()

# Sorting the DataFrame by 'imo'
fuel_imo_grouped_df = grouped_df.sort_values(by='IMO')

fuel_imo_grouped_df

# %%
fuel_imo_grouped_df

# %%
import pandas as pd

# Assuming 'fuel_imodcs' is your DataFrame containing fuel data
fuel_imodcs['Date_UTC'] = pd.to_datetime(fuel_imodcs['Date_UTC'])

# Assigning a unique number to each date within each vessel's data
fuel_imodcs['Days_running_imodcs'] = fuel_imodcs.groupby('IMO').cumcount() + 1

# Modifying the assigned day numbers to ensure they don't exceed 365
fuel_imodcs['Days_running_imodcs'] = fuel_imodcs['Days_running_imodcs'].apply(lambda x: x % 365 if x <= 365 else x % 365 + 1)

# Grouping by 'IMO' and summing the modified assigned numbers to calculate days run
grouped_dates = fuel_imodcs.groupby('IMO')['Days_running_imodcs'].agg(Days_running_imodcs='max')

# Calculating the count of missing days for each vessel
grouped_dates['Missing_days_imodcs'] = 365 - grouped_dates['Days_running_imodcs']

grouped_dates = grouped_dates.reset_index()

grouped_dates.head(7)

# %%
# Merging 'grouped_dates' DataFrame with 'fuel_imo_grouped_df' on the 'IMO' column
fuel_imo_grouped_df = pd.merge(fuel_imo_grouped_df, grouped_dates, on='IMO', how='left')

fuel_imo_grouped_df.head(7)

# %%
fuel_imo_grouped_df.to_csv('fuel_grouped_imo_df.csv')

# %% [raw]
# fuel_imo_grouped_df['IMO'] = fuel_imo_grouped_df['IMO'].astype(str)
# result_fuel_df = fuel_imo_grouped_df.merge(fuel_imo_grouped_df, left_on=['imo', 'month'], right_on=['IMO', 'month'], how='inner')
# print(result_fuel_df)

# %%
#result_fuel_df.to_csv('Data comparison.csv')

# %%
#lim

# %%
lim_df['Distance_lim']= lim_df[['Miles by gps','Manoeuvring miles by gps']].sum(axis=1)
lim_df['ME_hs_lima'] =  lim_df[['FOC_ME_RES_HS']]
lim_df['AUX_hs_lima'] =  lim_df[['FOC_AE_RES_HS']]
lim_df['Boiler_hs_lima'] =  lim_df[['FOC_BLR_RES_HS']]
 
lim_df['ME_ls_lima'] =  lim_df[['FOC_ME_RES_ULS','FOC_ME_RES_VLS']].sum(axis = 1) 
lim_df['AUX_ls_lima'] =  lim_df[['FOC_ME_RES_ULS','FOC_ME_RES_VLS']].sum(axis = 1)  
lim_df['Boiler_ls_lima'] =  lim_df[['FOC_BLR_RES_VLS','FOC_BLR_RES_ULS']] .sum(axis = 1)
 
lim_df['ME_uls_lima'] =  lim_df[['FOC_ME_DIS','FOC_ME_DIS_ULS','FOC_ME_DIS_VLS']].sum(axis = 1) 
lim_df['AUX_uls_lima'] =  lim_df[['FOC_AE_DIS','FOC_AE_DIS_ULS','FOC_AE_DIS_VLS']].sum(axis = 1) 
lim_df['Boiler_uls_lima'] =  lim_df[['FOC_BLR_DIS','FOC_BLR_DIS_ULS','FOC_BLR_DIS_VLS']] .sum(axis = 1)
 
lim_df['Total_ME_lima'] = lim_df[['ME_hs_lima','ME_ls_lima','ME_uls_lima']].sum(axis = 1)   
lim_df['Total_AUX_lima'] = lim_df[['AUX_hs_lima','AUX_ls_lima','AUX_uls_lima']].sum(axis = 1) 
lim_df['Total_Boiler_lima'] = lim_df[['Boiler_hs_lima','Boiler_ls_lima','Boiler_uls_lima']].sum(axis = 1)


lim_df["Total_HS"]=lim_df[['FOC_ME_RES_HS','FOC_AE_RES_HS',"FOC_BLR_RES_HS"]].sum(axis = 1) 
lim_df["Total_LS"]=lim_df[['FOC_ME_RES_ULS','FOC_ME_RES_VLS','FOC_ME_RES_ULS','FOC_ME_RES_VLS','FOC_BLR_RES_VLS','FOC_BLR_RES_ULS']].sum(axis = 1) 
lim_df["Total_ULS"]=lim_df[['FOC_ME_DIS','FOC_ME_DIS_ULS','FOC_ME_DIS_VLS','FOC_AE_DIS','FOC_AE_DIS_ULS','FOC_AE_DIS_VLS','FOC_BLR_DIS','FOC_BLR_DIS_ULS','FOC_BLR_DIS_VLS']].sum(axis = 1)

# %%
fuel_lim=lim_df[['ImoNumber','vName','Distance_lim','DateTimeUtc','Total_HS','Total_LS','Total_ULS','Total_ME_lima','Total_AUX_lima','Total_Boiler_lima']]

# %%
import pandas as pd

# Selecting specific columns from lim_df
#fuel_lim = lim_df[['ImoNumber', 'vName', 'Miles by gps', 'DateTimeUtc', 'Total_ME_lima', 'Total_AUX_lima', 'Total_Boiler_lima']]

# Convert 'DateTimeUtc' column to datetime
fuel_lim['DateTimeUtc'] = pd.to_datetime(fuel_lim['DateTimeUtc'])

# Extracting the month from 'DateTimeUtc'

# Grouping by 'ImoNumber' and 'month' and aggregating
fuel_lim_grouped = fuel_lim.groupby(['ImoNumber']).agg({
    'vName': 'first',  # Assuming 'vName' doesn't change within a month
    'Distance_lim': 'sum',
    'DateTimeUtc': 'first',
    'Total_HS':'sum',
    'Total_LS':'sum',
    'Total_ULS':'sum',
    'Total_ME_lima': 'sum',
    'Total_AUX_lima': 'sum',
    'Total_Boiler_lima': 'sum'
}).reset_index()

fuel_lim_grouped

# %%
import pandas as pd

# Assuming 'fuel_imodcs' is your DataFrame containing fuel data
fuel_lim['DateTimeUtc'] = pd.to_datetime(fuel_lim['DateTimeUtc'])

# Assigning a unique number to each date within each vessel's data
fuel_lim['Days_running_limasol'] = fuel_lim.groupby('ImoNumber').cumcount() + 1

# Modifying the assigned day numbers to ensure they don't exceed 365
fuel_lim['Days_running_limasol'] = fuel_lim['Days_running_limasol'].apply(lambda x: x % 365 if x <= 365 else x % 365 + 1)

# Grouping by 'IMO' and summing the modified assigned numbers to calculate days run
grouped_dates_lim = fuel_lim.groupby('ImoNumber')['Days_running_limasol'].agg(Days_running_limasol='max')
grouped_dates_lim['Lim_missing_days'] = 365 - grouped_dates_lim['Days_running_limasol']

grouped_dates_lim = grouped_dates_lim.reset_index()

grouped_dates_lim.head(7)

# %%
# Merging 'grouped_dates' DataFrame with 'fuel_imo_grouped_df' on the 'IMO' column
fuel_lim_grouped_df = pd.merge(fuel_lim_grouped, grouped_dates_lim, on='ImoNumber', how='left')

fuel_lim_grouped_df.head(7)

# %%
fuel_lim_grouped_df=fuel_lim_grouped_df[['ImoNumber','vName',"DateTimeUtc",'Days_running_limasol','Lim_missing_days','Distance_lim',"Total_HS","Total_LS","Total_ULS","Total_ME_lima","Total_AUX_lima","Total_Boiler_lima"]]

# %%
fuel_imo_grouped_df=fuel_imo_grouped_df[["IMO",'Date_UTC','Days_running_imodcs','Missing_days_imodcs','Distance','ME_Consumption_HFO','ME_Consumption_LFO','AE_Consumption_HFO','AE_Consumption_LFO','Boiler_Consumption_HFO','Boiler_Consumption_LFO','MGO_MDO','Total_ME','Total_AE','Total_Boiler']]

# %%
result_df= fuel_imo_grouped_df.merge(fuel_lim_grouped_df, left_on=['IMO'], right_on=['ImoNumber'], how='inner')

result_df

# %%
result_df['Diff_dist']=result_df['Distance_lim']-result_df['Distance']
result_df['Diff_ME']=result_df['Total_ME_lima']-result_df['Total_ME']
result_df['Diff_AUX']=result_df['Total_AUX_lima']-result_df['Total_AE']
result_df['Diff_Boiler']=result_df['Total_Boiler_lima']-result_df['Total_Boiler']

# %%
result_df.columns.to_list()

# %%
result_dc=result_df[['IMO','vName','DateTimeUtc','Days_running_imodcs','Missing_days_imodcs','Days_running_limasol','Lim_missing_days','Distance','Distance_lim',
'Diff_dist','Total_ME','Total_ME_lima','Diff_ME','Total_AE','Total_AUX_lima','Diff_AUX','Total_Boiler','Total_Boiler_lima','Diff_Boiler']]

# %%
result_dc.to_csv('result_dc.csv')

# %%
result=result_df[['IMO','vName','DateTimeUtc','Days_running_imodcs','Missing_days_imodcs','Days_running_limasol','Lim_missing_days','Distance','Distance_lim',
'Diff_dist','ME_Consumption_HFO','ME_Consumption_LFO','AE_Consumption_HFO','AE_Consumption_LFO','Boiler_Consumption_HFO','Boiler_Consumption_LFO','MGO_MDO','Total_ME','Total_AE','Total_Boiler','Total_HS',
 'Total_LS','Total_ULS','Total_ME_lima','Total_AUX_lima','Total_Boiler_lima','Diff_ME','Diff_AUX','Diff_Boiler']]

# %%
result.to_csv('result.csv')
