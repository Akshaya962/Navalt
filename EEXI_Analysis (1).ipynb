# %%
import pandas as pd
import numpy as np
import io
import json
from fpdf import FPDF
import matplotlib.pyplot as plt
import seaborn as sns
import requests
import requests
import io
import json
import numpy as np
from fpdf import FPDF
import seaborn as sns
from matplotlib import pyplot as plt
import matplotlib.dates as md
from fpdf import FPDF
from matplotlib.ticker import FuncFormatter
import matplotlib.ticker as ticker
import plotly.express as px
import plotly.graph_objects as go
import plotly.offline as pyo

vessel_name= 'Anastasia'
#types = 'Bulk'
#DWT



token="eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpZCI6NjA1LCJpZGVudGlmaWVyIjoiYWtzaGF5YUBuYXZhbHQuaW4iLCJjc2lkIjoiZDdiOTM0MWQtNTE5Mi00NjY0LWEzMWItMWYyZjEzNzAwNmM0IiwiaWF0IjoxNzE1MjIzNTMzLCJleHAiOjE3MTUzMDk5MzN9.fdhGTJec4S2CLgfS6S6-urY6Cu_Jyk861vC_Hry6nf4"
headers = {'Authorization': "Bearer {}".format(token)}

url="https://msc.oceanix.cloud/api/v1/vessels/9162631/generalinfo"
#url= https://msc.oceanix.cloud/api/v2/vessels/9235581/eexi

s = requests.get(url, headers=headers).json()
s = s['data']
info_df = pd.DataFrame(s)


token="eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpZCI6NjA1LCJpZGVudGlmaWVyIjoiYWtzaGF5YUBuYXZhbHQuaW4iLCJjc2lkIjoiZDdiOTM0MWQtNTE5Mi00NjY0LWEzMWItMWYyZjEzNzAwNmM0IiwiaWF0IjoxNzE1MjIzNTMzLCJleHAiOjE3MTUzMDk5MzN9.fdhGTJec4S2CLgfS6S6-urY6Cu_Jyk861vC_Hry6nf4"
headers = {'Authorization': "Bearer {}".format(token)}

url="https://msc.oceanix.cloud/api/v1/attributes"

a = requests.get(url, headers=headers).json()
 

df1 = pd.DataFrame(a['data'])
df1['attribute_id'] = df1['id'].values
 

df2 = pd.DataFrame(s)
 

df3 = pd.merge(left = df1, right = df2, on = 'attribute_id', how = 'outer')
 

df4  = df3[[  'attribute_id',  'imo', 'name', 'value','unit_x' ]]
 

df4['value_unit'] = df4['value'].fillna('') + " " + df4['unit_x'].fillna('')
 
mydict = dict(zip(df4['name'], df4['value_unit']))
mydict
# Out:
# C:\Users\Sujit\AppData\Local\Temp/ipykernel_108332/1337208212.py:62: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# {'Builder': 'Jiangnan Shipyard Group Co ',
#  'City': ' ',
#  'Country': ' ',
#  'Vessel Type': 'Container ',
#  'Current Class': 'DNV ',
#  'Date of Keel Laying': '20/05/1999 ',
#  'Year Built': '1998 ',
#  'Summer  DWT': '23825 T',
#  'Lightship': '9948.26 T',
#  'Displacement Scantling ': '33715 T',
#  'Bulbous Bow': 'Yes ',
#  'Maximum Speed': '20 kn',
#  'Complement': '25 ',
#  'Length O.A': '217.11 m',
#  'Length B.P': '201.74 m',
#  'Breadth Moulded': '26.66 m',
#  'Breadth Extreme': '26.66 m',
#  'Depth Moulded': '18.95 m',
#  'Draft Design': '11.41 m',
#  'Draft Scantling': '11.41 m',
# ...

# %%
def get_main_engine_data(mydict):
    
    vesseldata = {}
    vesseldata['Owner'] = mydict['Owner']
    vesseldata['Builder'] = mydict['Builder']
    vesseldata['Hull No.'] = mydict['Hull No.']
    vesseldata['IMO No'] = mydict['LR/IMO No.']
    vesseldata['Vessel Type'] = mydict['Vessel Type']
    vesseldata['Length O.A'] = mydict['Length O.A']
    vesseldata['Length B.P'] = mydict['Length B.P']
    vesseldata['Breadth Moulded'] = mydict['Breadth Moulded']
    vesseldata['Depth Moulded'] = mydict['Depth Moulded']
    vesseldata['Gross Tonnage'] = mydict['Gross Tonnage']
    vesseldata['Summer  DWT'] = mydict['Summer  DWT']
    vesseldata['Number of Main Engines'] = mydict['Number of Main Engines']
    vesseldata['Total Number Of Auxiliary Engine'] = mydict['Total Number Of Auxiliary Engine ']
    
    ################################################################################################################## 
    
    mecount = int(mydict['Number of Main Engines'])
    print('mecount', mecount)
    medata = {}
    for i in range(1, (mecount+1)):
        if i == 1:
            medata['Main Engine_'+str(i)+ ' Make'] = mydict['Main Engine_'+str(i)+ ' Make']
            medata['ME-'+str(i)+ ' Type'] = mydict['ME-'+str(i)+ ' Type']
            medata['ME-'+str(i)+ ' MCR RPM'] = mydict['ME-'+str(i)+ ' MCR RPM']
            medata['ME'+str(i)+ '- SFOC at 75% MCR (ISO Corrected)'] = mydict['ME'+str(i)+ '- SFOC at 75% MCR (ISO Corrected)']
            medata['ME-'+str(i)+ ' New MCR RPM'] = mydict['ME-'+str(i)+ ' New MCR RPM'] 
     
        elif i > 1:
            medata['Main Engine_'+str(i)+ ' Make'] = mydict['Main Engine_'+str(i)+ '  Make']
            medata['ME-'+str(i)+ ' Type'] = mydict['ME-'+str(i)+ ' Type']
            medata['ME-'+str(i)+ ' MCR RPM'] = mydict['ME-'+str(i)+ ' MCR RPM']
            medata['ME'+str(i)+ '- SFOC at 75% MCR (ISO Corrected)'] = mydict['ME'+str(i)+ '- SFOC at 75% MCR (ISO Corrected)'] 
            medata['ME-'+str(i)+ ' New MCR RPM'] = mydict['ME-'+str(i)+ ' New MCR RPM']
    ##################################################################################################################        
    aecount = int(mydict['Total Number Of Auxiliary Engine '])
    
    print('aecount', aecount)
    aedata = {}
    for i in range(1, (aecount+1)):
 
        aedata['AE'+str(i)+ '- Engine Maker'] = mydict['AE'+str(i)+ '- Engine Maker']
        aedata['AE'+str(i)+ '- Engine Type'] = mydict['AE'+str(i)+ '- Engine Type']
        aedata['AE'+str(i)+ '- Maximum Continuous Rate- Mechanical'] = mydict['AE'+str(i)+ '- Maximum Continuous Rate- Mechanical']
        aedata['AE'+str(i)+ '-SFOC at 50%Load (ISO Corrected)'] = mydict['AE'+str(i)+ '-SFOC at 50%Load (ISO Corrected)']   
        aedata['AE'+str(i)+ '-Fuel Used to determine SFOC'] = mydict['AE'+str(i)+ '-Fuel Used to determine SFOC']     
 
    
    
    return vesseldata, medata, aedata
get_main_engine_data(mydict)
# Out:
# mecount 2
# aecount 2
# ({'Owner': 'ASLI Oceanway Limited ',
#   'Builder': 'Jiangnan Shipyard Group Co ',
#   'Hull No.': '2243 ',
#   'IMO No': '9162631 ',
#   'Vessel Type': 'Container ',
#   'Length O.A': '217.11 m',
#   'Length B.P': '201.74 m',
#   'Breadth Moulded': '26.66 m',
#   'Depth Moulded': '18.95 m',
#   'Gross Tonnage': '24836 T',
#   'Summer  DWT': '23825 T',
#   'Number of Main Engines': '2 ',
#   'Total Number Of Auxiliary Engine': '2 '},
#  {'Main Engine_1 Make': 'Wartsila Sulzer ',
#   'ME-1 Type': '16 ZAV 40 S ',
#   'ME-1 MCR RPM': '510 RPM',
#   'ME1- SFOC at 75% MCR (ISO Corrected)': 'ME2-184.91 g/kwh',
#   'ME-1 New MCR RPM': '510 RPM',
#   'Main Engine_2 Make': ' ',
#   'ME-2 Type': ' ',
#   'ME-2 MCR RPM': ' RPM',
#   'ME2- SFOC at 75% MCR (ISO Corrected)': ' g/kwh',
#   'ME-2 New MCR RPM': ' RPM'},
#  {'AE1- Engine Maker': 'Yanmar ',
#   'AE1- Engine Type': '6N260L-EN  ',
#   'AE1- Maximum Continuous Rate- Mechanical': '1342 kW',
# ...
