# %%
import pandas as pd
import requests
import io
import json
import numpy as np
from fpdf import FPDF
import seaborn as sns
from matplotlib import pyplot as plt
import matplotlib.dates as md
from fpdf import FPDF
from matplotlib.ticker import FuncFormatter
import matplotlib.ticker as ticker
import plotly.graph_objects as go
import plotly.express as px
import plotly.offline as pyo
from datetime import datetime

# %%
sea_state ="0"
vessel_name= "ANASTASIA%20-%209625970"
date= "From%2024-Sep-2021%20TO%2024-Mar-2022_BM"

# %%
per_result={
    "performance_result": {
        "tab1": {
            "table1": [
                {
                    "5": 11.6,
                    "6": 12.5,
                    "7": 13.3,
                    "8": 14.1,
                    "9": 14.8,
                    "10": 15.5,
                    "11": 16.1,
                    "12": 16.7,
                    "13": 17.3,
                    "Speed/Draft": 10
                },
                {
                    "5": 14.8,
                    "6": 16,
                    "7": 17.1,
                    "8": 18,
                    "9": 19,
                    "10": 19.8,
                    "11": 20.6,
                    "12": 21.4,
                    "13": 22.2,
                    "Speed/Draft": 11
                },
                {
                    "5": 18.5,
                    "6": 20,
                    "7": 21.4,
                    "8": 22.6,
                    "9": 23.8,
                    "10": 24.8,
                    "11": 25.9,
                    "12": 26.8,
                    "13": 27.8,
                    "Speed/Draft": 12
                },
                {
                    "5": 22.8,
                    "6": 24.6,
                    "7": 26.3,
                    "8": 27.8,
                    "9": 29.2,
                    "10": 30.6,
                    "11": 31.8,
                    "12": 33,
                    "13": 34.1,
                    "Speed/Draft": 13
                }
            ],
            "table2": [
                {
                    "5": 2606,
                    "6": 2814,
                    "7": 3003,
                    "8": 3177,
                    "9": 3339,
                    "10": 3491,
                    "11": 3635,
                    "12": 3771,
                    "13": 3900,
                    "Speed/Draft": 10
                },
                {
                    "5": 3338,
                    "6": 3606,
                    "7": 3848,
                    "8": 4071,
                    "9": 4279,
                    "10": 4473,
                    "11": 4657,
                    "12": 4831,
                    "13": 4997,
                    "Speed/Draft": 11
                },
                {
                    "5": 4186,
                    "6": 4521,
                    "7": 4825,
                    "8": 5105,
                    "9": 5365,
                    "10": 5609,
                    "11": 5839,
                    "12": 6057,
                    "13": 6266,
                    "Speed/Draft": 12
                },
                {
                    "5": 5154,
                    "6": 5567,
                    "7": 5941,
                    "8": 6286,
                    "9": 6606,
                    "10": 6906,
                    "11": 7190,
                    "12": 7459,
                    "13": 7715,
                    "Speed/Draft": 13
                }
            ],
            "chart1": [
                {
                    "category": "5",
                    "fo_consumption": 11.6,
                    "speed": 10
                },
                {
                    "category": "5",
                    "fo_consumption": 14.8,
                    "speed": 11
                },
                {
                    "category": "5",
                    "fo_consumption": 18.5,
                    "speed": 12
                },
                {
                    "category": "5",
                    "fo_consumption": 22.8,
                    "speed": 13
                },
                {
                    "category": "6",
                    "fo_consumption": 12.5,
                    "speed": 10
                },
                {
                    "category": "6",
                    "fo_consumption": 16,
                    "speed": 11
                },
                {
                    "category": "6",
                    "fo_consumption": 20,
                    "speed": 12
                },
                {
                    "category": "6",
                    "fo_consumption": 24.6,
                    "speed": 13
                },
                {
                    "category": "7",
                    "fo_consumption": 13.3,
                    "speed": 10
                },
                {
                    "category": "7",
                    "fo_consumption": 17.1,
                    "speed": 11
                },
                {
                    "category": "7",
                    "fo_consumption": 21.4,
                    "speed": 12
                },
                {
                    "category": "7",
                    "fo_consumption": 26.3,
                    "speed": 13
                },
                {
                    "category": "8",
                    "fo_consumption": 14.1,
                    "speed": 10
                },
                {
                    "category": "8",
                    "fo_consumption": 18,
                    "speed": 11
                },
                {
                    "category": "8",
                    "fo_consumption": 22.6,
                    "speed": 12
                },
                {
                    "category": "8",
                    "fo_consumption": 27.8,
                    "speed": 13
                },
                {
                    "category": "9",
                    "fo_consumption": 14.8,
                    "speed": 10
                },
                {
                    "category": "9",
                    "fo_consumption": 19,
                    "speed": 11
                },
                {
                    "category": "9",
                    "fo_consumption": 23.8,
                    "speed": 12
                },
                {
                    "category": "9",
                    "fo_consumption": 29.2,
                    "speed": 13
                },
                {
                    "category": "10",
                    "fo_consumption": 15.5,
                    "speed": 10
                },
                {
                    "category": "10",
                    "fo_consumption": 19.8,
                    "speed": 11
                },
                {
                    "category": "10",
                    "fo_consumption": 24.8,
                    "speed": 12
                },
                {
                    "category": "10",
                    "fo_consumption": 30.6,
                    "speed": 13
                },
                {
                    "category": "11",
                    "fo_consumption": 16.1,
                    "speed": 10
                },
                {
                    "category": "11",
                    "fo_consumption": 20.6,
                    "speed": 11
                },
                {
                    "category": "11",
                    "fo_consumption": 25.9,
                    "speed": 12
                },
                {
                    "category": "11",
                    "fo_consumption": 31.8,
                    "speed": 13
                },
                {
                    "category": "12",
                    "fo_consumption": 16.7,
                    "speed": 10
                },
                {
                    "category": "12",
                    "fo_consumption": 21.4,
                    "speed": 11
                },
                {
                    "category": "12",
                    "fo_consumption": 26.8,
                    "speed": 12
                },
                {
                    "category": "12",
                    "fo_consumption": 33,
                    "speed": 13
                },
                {
                    "category": "13",
                    "fo_consumption": 17.3,
                    "speed": 10
                },
                {
                    "category": "13",
                    "fo_consumption": 22.2,
                    "speed": 11
                },
                {
                    "category": "13",
                    "fo_consumption": 27.8,
                    "speed": 12
                },
                {
                    "category": "13",
                    "fo_consumption": 34.1,
                    "speed": 13
                }
            ],
            "chart2": [
                {
                    "category": "5",
                    "fo_consumption": 2606,
                    "speed": 10
                },
                {
                    "category": "5",
                    "fo_consumption": 3338,
                    "speed": 11
                },
                {
                    "category": "5",
                    "fo_consumption": 4186,
                    "speed": 12
                },
                {
                    "category": "5",
                    "fo_consumption": 5154,
                    "speed": 13
                },
                {
                    "category": "6",
                    "fo_consumption": 2814,
                    "speed": 10
                },
                {
                    "category": "6",
                    "fo_consumption": 3606,
                    "speed": 11
                },
                {
                    "category": "6",
                    "fo_consumption": 4521,
                    "speed": 12
                },
                {
                    "category": "6",
                    "fo_consumption": 5567,
                    "speed": 13
                },
                {
                    "category": "7",
                    "fo_consumption": 3003,
                    "speed": 10
                },
                {
                    "category": "7",
                    "fo_consumption": 3848,
                    "speed": 11
                },
                {
                    "category": "7",
                    "fo_consumption": 4825,
                    "speed": 12
                },
                {
                    "category": "7",
                    "fo_consumption": 5941,
                    "speed": 13
                },
                {
                    "category": "8",
                    "fo_consumption": 3177,
                    "speed": 10
                },
                {
                    "category": "8",
                    "fo_consumption": 4071,
                    "speed": 11
                },
                {
                    "category": "8",
                    "fo_consumption": 5105,
                    "speed": 12
                },
                {
                    "category": "8",
                    "fo_consumption": 6286,
                    "speed": 13
                },
                {
                    "category": "9",
                    "fo_consumption": 3339,
                    "speed": 10
                },
                {
                    "category": "9",
                    "fo_consumption": 4279,
                    "speed": 11
                },
                {
                    "category": "9",
                    "fo_consumption": 5365,
                    "speed": 12
                },
                {
                    "category": "9",
                    "fo_consumption": 6606,
                    "speed": 13
                },
                {
                    "category": "10",
                    "fo_consumption": 3491,
                    "speed": 10
                },
                {
                    "category": "10",
                    "fo_consumption": 4473,
                    "speed": 11
                },
                {
                    "category": "10",
                    "fo_consumption": 5609,
                    "speed": 12
                },
                {
                    "category": "10",
                    "fo_consumption": 6906,
                    "speed": 13
                },
                {
                    "category": "11",
                    "fo_consumption": 3635,
                    "speed": 10
                },
                {
                    "category": "11",
                    "fo_consumption": 4657,
                    "speed": 11
                },
                {
                    "category": "11",
                    "fo_consumption": 5839,
                    "speed": 12
                },
                {
                    "category": "11",
                    "fo_consumption": 7190,
                    "speed": 13
                },
                {
                    "category": "12",
                    "fo_consumption": 3771,
                    "speed": 10
                },
                {
                    "category": "12",
                    "fo_consumption": 4831,
                    "speed": 11
                },
                {
                    "category": "12",
                    "fo_consumption": 6057,
                    "speed": 12
                },
                {
                    "category": "12",
                    "fo_consumption": 7459,
                    "speed": 13
                },
                {
                    "category": "13",
                    "fo_consumption": 3900,
                    "speed": 10
                },
                {
                    "category": "13",
                    "fo_consumption": 4997,
                    "speed": 11
                },
                {
                    "category": "13",
                    "fo_consumption": 6266,
                    "speed": 12
                },
                {
                    "category": "13",
                    "fo_consumption": 7715,
                    "speed": 13
                }
            ]
        }
    }
}

# %%
fo_table = pd.DataFrame.from_dict(per_result['performance_result']["tab1"]["table1"])
cols = ['Speed/Draft'] + [col for col in fo_table.columns if col != 'Speed/Draft']
fo_table = fo_table[cols]
fo_table


po_table = pd.DataFrame.from_dict(per_result['performance_result']["tab1"]["table2"])
cols = ['Speed/Draft'] + [col for col in po_table.columns if col != 'Speed/Draft']
po_table = po_table[cols]
po_table


fo_Chart = pd.DataFrame.from_dict(per_result['performance_result']["tab1"]["chart1"])



po_Chart = pd.DataFrame.from_dict(per_result['performance_result']["tab1"]["chart2"])



fo_color = (fo_table.shape[1])-1
power_color=(po_table.shape[1])-1


# color_lst = ['blue','yellow','red','violet','green','cyan','pink','gray','orange','purple','indigo','magenta']
color_lst = ['brown', 'darkviolet', 'red', 'green', 'orange', 'blue', 'yellow', 'cyan', 'pink', 'gray', 'olive', 'purple', 'indigo', 'magenta', 'beige', 'black', 'teal', 'maroon', 'navy', 'turquoise', 'salmon', 'gold', 'silver', 'coral', 'violet', 'lime', 'orchid', 'plum', 'khaki']

new_color_lst1 = []
new_color_lst2 = []

for z in range (0,fo_color):
    color_sel = color_lst[z]
    new_color_lst1.append(color_sel)
new_color_lst1 


for z in range (0,power_color):
    color_sel = color_lst[z]
    new_color_lst2.append(color_sel)
new_color_lst2

####################
fo_column_head = list(fo_table.columns.values)
fo_object =fo_table.astype(str)
power_column_head = list(po_table.columns.values)
power_object =po_table.astype(str)




#_______________________Graph________________________________

import matplotlib.pyplot as plt
import seaborn as sns

# Assuming fo_Chart, po_Chart, new_color_lst1, and new_color_lst2 are already defined

# Plot 1
fig_1, axes = plt.subplots(1, 1, figsize=(10, 6))  # Increase figure size
sns.lineplot(data=fo_Chart, x='speed', y='fo_consumption', marker='o', markersize=5, lw=1, hue='category', palette=new_color_lst1)
axes.set_xlabel('Speed (knots)', fontweight="bold", size=10)
axes.set_ylabel('FO/24 Hrs (tonne)', fontweight="bold", size=10)
axes.legend_.set_title(None)
axes.legend(loc='upper left', bbox_to_anchor=(1, 1))  # Place legend outside

fig_1.tight_layout()
fig_1.savefig('fo_pr.png')
#plt.clf()
fig_1.show()

# Plot 2
fig_2, axes = plt.subplots(1, 1, figsize=(10, 6))  # Increase figure size
sns.lineplot(data=po_Chart, x='speed', y='fo_consumption', marker='o', markersize=5, lw=1, hue='category', palette=new_color_lst2)
axes.set_xlabel('Speed (knots)', fontweight="bold", size=10)
axes.set_ylabel('Power (KW)', fontweight="bold", size=10)
axes.legend_.set_title(None)
axes.legend(loc='upper left', bbox_to_anchor=(1, 1))  # Place legend outside

fig_2.tight_layout()
fig_2.savefig('po_pr.png')
#plt.clf()
fig_2.show()
# Out:
# C:\Users\akshaya\AppData\Local\Temp\ipykernel_22796\1228990582.py:69: UserWarning:
#
# Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#
# C:\Users\akshaya\AppData\Local\Temp\ipykernel_22796\1228990582.py:82: UserWarning:
#
# Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %%
pdf = FPDF()
#***********************************************  page 1 **********************************************************#
pdf.add_page()
pdf.set_font('Arial', 'B', 18)

#pdf.image(oceanix_logo_path,15,15,w=35)
#pdf.image(msc_logo_path,160,12,w=25)
pdf.set_xy(65,15)
pdf.set_text_color(25,47,133)
pdf.cell(170, 60, 'PERFORMANCE RESULTS',ln=True)
pdf.set_text_color(0,0,0)
pdf.set_line_width(1)
pdf.line(10, 50, 190, 50)#(x_start, y_start, x_end, y_end)
pdf.set_line_width(0.2)
pdf.set_font('Arial', "",12)
pdf.set_xy(10,55)
#pdf.multi_cell(80,14.5,"Report Date :"+" "+ report_prepared_date, align='R')


pdf.cell(10, 2, "Vessel Name :"+" "+vessel_name,ln=True)
pdf.cell(10, 12,"Date :"+" "+ date,ln=True)

pdf.set_line_width(0)
pdf.set_text_color(0,0,0)
pdf.set_font('Arial', "",14)
pdf.cell(15, 25,"Sea State :"+" "+ sea_state,ln=True)

pdf.line(10, 70, 190, 70)
pdf.set_font('Arial', 'B', 18)
pdf.set_text_color(25,47,133)
pdf.cell(180, 18, 'FO Calculator Table',ln=True,align='C')

spacing = 3
fo_head = [fo_column_head]
fo_values = fo_object.values.tolist()
pdf.set_font("Arial", 'B', size=6.5)
pdf.set_text_color(0, 0, 0)
pdf.set_fill_color(21, 55, 188)

# Calculate the size of each column name
col_widths = [pdf.get_string_width(str(item)) + 8 for item in fo_head[0]]

row_height = pdf.font_size

# Draw header with dynamic column width
for item, width in zip(fo_head[0], col_widths):
    pdf.set_text_color(255, 255, 255)
    pdf.cell(width, row_height * spacing, txt=item, border=1, fill=True)
pdf.ln(row_height * spacing)

pdf.set_font("Arial", size=7)
pdf.set_text_color(0, 0, 0)

# Draw data with dynamic column width
for row in fo_values:
    for item, width in zip(row, col_widths):
        pdf.cell(width, row_height * spacing, txt=item, border=1)
    pdf.ln(row_height * spacing)


#Page Number
pdf.set_y(273)
pdf.set_font('Arial', 'I', 8)
pdf.cell(0,2,'Page %s' % pdf.page_no(),align="R")  

#***********************************************  page 2 **********************************************************#


pdf.add_page()
#pdf.set_xy(10,50)
pdf.set_font('Arial', 'B', 18)
pdf.set_text_color(25,47,133)
pdf.cell(180, 18, 'FO Calculator Chart',ln=True,align='C')
pdf.image("fo_pr.png",15,25,w=170,h=100) 
pdf.set_xy(10,135)
pdf.cell(180, 10, 'Power Calculator Chart',ln=True,align='C')
pdf.image("po_pr.png",15,145,w=170,h=105) 


#Page Number
pdf.set_y(273)
pdf.set_font('Arial', 'I', 8)
pdf.cell(0,2,'Page %s' % pdf.page_no(),align="R")  
#***********************************************  page 3**********************************************************#
pdf.add_page()

pdf.set_font('Arial', 'B', 18)
pdf.set_text_color(25,47,133)
pdf.cell(180, 18, 'Power Calculator Table',ln=True,align='C')


pdf.set_line_width(0)
pdf.set_text_color(0,0,0)
spacing = 3
power_head = [power_column_head]
power_values = power_object.values.tolist()
pdf.set_font("Arial", 'B', size=6.5)
pdf.set_text_color(0, 0, 0)
pdf.set_fill_color(21, 55, 188)

# Calculate the size of each column name
col_widths = [pdf.get_string_width(str(item)) + 8 for item in power_head[0]]

row_height = pdf.font_size

# Draw header with dynamic column width
for item, width in zip(power_head[0], col_widths):
    pdf.set_text_color(255, 255, 255)
    pdf.cell(width, row_height * spacing, txt=item, border=1, fill=True)
pdf.ln(row_height * spacing)

pdf.set_font("Arial", size=7)
pdf.set_text_color(0, 0, 0)

# Draw data with dynamic column width
for row in power_values:
    for item, width in zip(row, col_widths):
        pdf.cell(width, row_height * spacing, txt=item, border=1)
    pdf.ln(row_height * spacing)




#Page Number
pdf.set_y(273)
pdf.set_font('Arial', 'I', 8)
pdf.cell(0,2,'Page %s' % pdf.page_no(),align="R")  
print("Downloading")

pdf.output('performance_result.pdf')
print("Downloaded")
# Out:
# Downloading
# Downloaded
