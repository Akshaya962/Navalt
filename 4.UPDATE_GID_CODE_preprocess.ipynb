# %%
import warnings
warnings.filterwarnings("ignore")
import pandas as pd

# %% [markdown]
# # CHARTER & SORRENTO

# %%
charter_remark = pd.read_excel(r"D:\Navalt\MSC\2024\ESI\Group A\JAN24 TO JUN24\OUTPUT\CHARTER MISSING BDNs refl.xlsx")

# %%
charter_remarks = charter_remark[charter_remark['report_type'] == 'REFL']

# %%
charter_remarks.columns.to_list()
# Out:
# ['id',
#  'gid',
#  'vessel_name',
#  'imo',
#  'voy',
#  'corrected_date',
#  'report_date_time',
#  'report_date_time_offset',
#  'report_type',
#  'status',
#  'latitude',
#  'longitude',
#  'm_e_foc',
#  'cargo_total',
#  'has_cargo',
#  'steaming_time',
#  'total_m_e_hours_fuel_only',
#  'miles_by_gps',
#  'oil_cyl',
#  'speed_by_log',
#  'speed_by_gps',
#  'rpm',
#  'slip',
#  'wind_direction',
#  'wind_speed',
#  'draft_aft',
#  'draft_fwd',
#  'displacement',
#  'course_at_sea',
#  'wave_height',
#  'sea_direction',
#  'cargo_total_teu',
#  'ambient_temp',
#  'sw_temp',
#  'miles_by_speed_log',
#  'eta_port_code',
#  'eta_date_time',
#  'eta_date_time_offset',
#  'eta_port',
#  'time_change',
#  'time_sea',
#  'temp_min',
#  'temp_max',
#  'requested_speed',
#  'rem_dist_to_pilot',
#  'rem_time_to_pilot',
#  'total_unplnd_stpge_tech',
#  'total_unplnd_stpge_ope_wx',
#  'reefers_positive_plugged',
#  'reefers_negative_plugged',
#  'me_total_revs_counter',
#  'port_code',
# ...

# %%
charter_remarks = charter_remarks.rename(columns={
    'gid': 'GID',
     'imo'  :     'IMO_No',
    'vessel_name'   :  'VSL',
    'report_date_time'  :'REPORT_DATE_TIME',
    'sulphur_content_pc': 'Sulphur_Content_PC',
    'quantity': 'Quantity',
    'port_delivery': 'Port_Delivery',
    'product_quality': 'Product_Quality',
    'delivery': 'Delivery',
    'bdn': 'BDN'
})

# %%
charter_remarks
# Out:
#           id                                   GID                VSL  \
# 0    4493242  3eacc476-c023-494d-a6ce-a1aa6378218d        MSC QINGDAO
# 1    4490311  d54b3fce-c7e4-4423-bd60-99066cd81cc5              KOTKA
# 2    4494685  a0467399-7302-4cfa-a98e-01ae7ba67a4c              ALANA
# 3    4492927  a030ad08-a899-45f3-8fb8-c828f0d620bc      MSC BOSPHORUS
# 4    4493196  d52d5be1-85ba-4971-99cf-d1cefe281b8c          MED CESME
# ..       ...                                   ...                ...
# 385  4400611  5d08330f-f1fe-437d-9978-56f153b43d29     HUBERT SCHULTE
# 386  4400612  4ce4295a-b97c-47d5-be01-7e7c08138ced     HUBERT SCHULTE
# 387  4394005  23856d53-69cf-4984-ba31-2a1c6678e5ea     CONTI CHIVALRY
# 388  4400564  a1695f38-5432-4fd1-b96c-10e1b23789be    HERMANN SCHULTE
# 389  4403161  d8ced3a9-4ae4-45f7-8309-df6814f5441f  SPIRIT OF KOLKATA
#
#       IMO_No     voy corrected_date REPORT_DATE_TIME report_date_time_offset  \
# ...

# %%
client_charter_bdn = pd.read_excel(r"D:\Navalt\MSC\2024\ESI\Group A\JAN24 TO JUN24\CLIENT FILE\CHARTER MISSING BDNs.xlsx")

# %%
client_charter_bdn.columns.tolist()
# Out:
# ['id',
#  'gid',
#  'vessel_name',
#  'imo',
#  'voy',
#  'corrected_date',
#  'report_date_time',
#  'report_date_time_offset',
#  'report_type',
#  'status',
#  'latitude',
#  'longitude',
#  'm_e_foc',
#  'cargo_total',
#  'has_cargo',
#  'steaming_time',
#  'total_m_e_hours_fuel_only',
#  'miles_by_gps',
#  'oil_cyl',
#  'speed_by_log',
#  'speed_by_gps',
#  'rpm',
#  'slip',
#  'wind_direction',
#  'wind_speed',
#  'draft_aft',
#  'draft_fwd',
#  'displacement',
#  'course_at_sea',
#  'wave_height',
#  'sea_direction',
#  'cargo_total_teu',
#  'ambient_temp',
#  'sw_temp',
#  'miles_by_speed_log',
#  'eta_port_code',
#  'eta_date_time',
#  'eta_date_time_offset',
#  'eta_port',
#  'time_change',
#  'time_sea',
#  'temp_min',
#  'temp_max',
#  'requested_speed',
#  'rem_dist_to_pilot',
#  'rem_time_to_pilot',
#  'total_unplnd_stpge_tech',
#  'total_unplnd_stpge_ope_wx',
#  'reefers_positive_plugged',
#  'reefers_negative_plugged',
#  'me_total_revs_counter',
#  'port_code',
# ...

# %%
#client_charter_bdn = client_charter_bdn.rename(columns=lambda x: x.lower(), inplace=True)
client_charter_bdn = client_charter_bdn.rename(columns={
    'gid': 'GID',
      'imo'  :     'IMO_No',
    'vessel_name'   :  'VSL',
    'report_date_time'  :'REPORT_DATE_TIME',
    'sulphur_content_pc': 'Sulphur_Content_PC',
    'quantity': 'Quantity',
    'port_delivery': 'Port_Delivery',
    'product_quality': 'Product_Quality',
    'delivery': 'Delivery',
    'bdn': 'BDN'
})

# %%
client_charter_bdn
# Out:
#          id                                   GID                VSL   IMO_No  \
# 0   4508826  13c39c39-a7fb-455a-a332-4f3a2ae8ebd2              ALANA  9297589
# 1   4537973  a6cd03e5-341b-4070-b442-1b5f1d146b9f      AS CALIFORNIA  9342695
# 2   4510435  91e79d0b-6040-4dcd-b276-1819db70bc72      AS CALIFORNIA  9342695
# 3   4492974  18db67d8-62dc-4035-a72a-3b93931a7a39       ATHENS GLORY  9247766
# 4   4530377  bb03d4d8-1951-4d66-aafd-a024fd202af2        CAPE SOUNIO  9727625
# ..      ...                                   ...                ...      ...
# 81  4493169  eb234fe9-286c-4bd5-9b2a-ed2ed9db4042       MSC TURIN II  9256365
# 82  4544776  14c84554-7fd6-4ebc-a391-62962d4d9ce3  SPIRIT OF CHENNAI  9813840
# 83  4544837  0df390b6-f52d-4aa8-ba4a-efdd8a991d11  SPIRIT OF CHENNAI  9813840
# 84  4403240  40ffe7ad-169e-464c-9854-9b1c09e1be4e  SPIRIT OF CHENNAI  9813840
# 85  4503605  1b985475-c5c5-45f0-87b0-12a8fa04261a  SPIRIT OF CHENNAI  9813840
#
# ...

# %%
value_map = dict(zip(client_charter_bdn['GID'], client_charter_bdn['Sulphur_Content_PC']))
charter_remarks['Sulphur_Content_PC'] = charter_remarks['GID'].map(value_map).fillna(charter_remarks['Sulphur_Content_PC'])

value_map = dict(zip(client_charter_bdn['GID'], client_charter_bdn['REPORT_DATE_TIME']))
charter_remarks['REPORT_DATE_TIME'] = charter_remarks['GID'].map(value_map).fillna(charter_remarks['REPORT_DATE_TIME'])

value_map_1 = dict(zip(client_charter_bdn['GID'], client_charter_bdn['Quantity']))
charter_remarks['Quantity'] = charter_remarks['GID'].map(value_map_1).fillna(charter_remarks['Quantity'])


value_map_2 = dict(zip(client_charter_bdn['GID'], client_charter_bdn['Product_Quality']))
charter_remarks['Product_Quality'] = charter_remarks['GID'].map(value_map_2).fillna(charter_remarks['Product_Quality'])

value_map_2 = dict(zip(client_charter_bdn['GID'], client_charter_bdn['Delivery']))
charter_remarks['Delivery'] = charter_remarks['GID'].map(value_map_2).fillna(charter_remarks['Delivery'])
charter_remarks
# Out:
#           id                                   GID                VSL  \
# 0    4493242  3eacc476-c023-494d-a6ce-a1aa6378218d        MSC QINGDAO
# 1    4490311  d54b3fce-c7e4-4423-bd60-99066cd81cc5              KOTKA
# 2    4494685  a0467399-7302-4cfa-a98e-01ae7ba67a4c              ALANA
# 3    4492927  a030ad08-a899-45f3-8fb8-c828f0d620bc      MSC BOSPHORUS
# 4    4493196  d52d5be1-85ba-4971-99cf-d1cefe281b8c          MED CESME
# ..       ...                                   ...                ...
# 385  4400611  5d08330f-f1fe-437d-9978-56f153b43d29     HUBERT SCHULTE
# 386  4400612  4ce4295a-b97c-47d5-be01-7e7c08138ced     HUBERT SCHULTE
# 387  4394005  23856d53-69cf-4984-ba31-2a1c6678e5ea     CONTI CHIVALRY
# 388  4400564  a1695f38-5432-4fd1-b96c-10e1b23789be    HERMANN SCHULTE
# 389  4403161  d8ced3a9-4ae4-45f7-8309-df6814f5441f  SPIRIT OF KOLKATA
#
#       IMO_No     voy corrected_date REPORT_DATE_TIME report_date_time_offset  \
# ...

# %%
ignored_data = client_charter_bdn[client_charter_bdn['REMARKS']=='IGNORE']
ignored_data_lst = ignored_data['GID'].unique().tolist()
ignored_data_lst
# Out:
# ['bb03d4d8-1951-4d66-aafd-a024fd202af2',
#  '96e1fa95-9144-4e59-9310-769dff4cfdc3',
#  '280bf040-4cef-49d6-9692-2031bef4785a',
#  'ee6b6917-0a6b-4d3e-8892-88ee59c210fa',
#  '9f693bd8-3458-40b8-85d0-137db5d38f8c',
#  'cf760d76-632f-454f-a967-bda23370f3d6',
#  '8435752a-d767-40b0-8a0a-10a5d96bd1b5',
#  '42402b6d-8e6e-4a38-bdce-5bc9ef993dcc',
#  '14c84554-7fd6-4ebc-a391-62962d4d9ce3']

# %%
file_change_refl_vtout_ignored = charter_remarks[~charter_remarks['GID'].isin(ignored_data_lst)]
cr=file_change_refl_vtout_ignored[['GID','IMO_No','VSL','REPORT_DATE_TIME','Sulphur_Content_PC','Quantity','Port_Delivery','Product_Quality','Delivery']]

# %%
# charter_remarks_db = file_change_refl_vtout_ignored[['GID','Sulphur_Content_PC','Quantity','Port_Delivery','Product_Quality','Delivery']]
# charter_remarks_db

# %%
#charter_remarks_db['Sulphur_Content_PC'].isna().sum()
cr['Sulphur_Content_PC'].isna().sum()
# Out:
# 0

# %%
# chart_nan = charter_remarks_db[charter_remarks_db['Sulphur_Content_PC'].isna()]
# chart_nan
chart_nan = cr[cr['Sulphur_Content_PC'].isna()]
chart_nan
# Out:
# Empty DataFrame
# Columns: [GID, IMO_No, VSL, REPORT_DATE_TIME, Sulphur_Content_PC, Quantity, Port_Delivery, Product_Quality, Delivery]
# Index: []

# %%
# charter_remarks_db['BDN'] = 'YES'
# charter_remarks_db
cr['BDN'] = 'YES'
cr
# Out:
#                                       GID   IMO_No                VSL  \
# 0    3eacc476-c023-494d-a6ce-a1aa6378218d  9256470        MSC QINGDAO
# 1    d54b3fce-c7e4-4423-bd60-99066cd81cc5  9085534              KOTKA
# 2    a0467399-7302-4cfa-a98e-01ae7ba67a4c  9297589              ALANA
# 3    a030ad08-a899-45f3-8fb8-c828f0d620bc  9247742      MSC BOSPHORUS
# 4    d52d5be1-85ba-4971-99cf-d1cefe281b8c  9256365          MED CESME
# ..                                    ...      ...                ...
# 385  5d08330f-f1fe-437d-9978-56f153b43d29  9535204     HUBERT SCHULTE
# 386  4ce4295a-b97c-47d5-be01-7e7c08138ced  9535204     HUBERT SCHULTE
# 387  23856d53-69cf-4984-ba31-2a1c6678e5ea  9293791     CONTI CHIVALRY
# 388  a1695f38-5432-4fd1-b96c-10e1b23789be  9535187    HERMANN SCHULTE
# 389  d8ced3a9-4ae4-45f7-8309-df6814f5441f  9813838  SPIRIT OF KOLKATA
#
#     REPORT_DATE_TIME  Sulphur_Content_PC  Quantity Port_Delivery  \
# ...

# %% [markdown]
# ### SORRENTO

# %%
sorrento_remark = pd.read_excel(r"D:\Navalt\MSC\2024\ESI\Group A\JAN24 TO JUN24\OUTPUT\SORRENTO MISSING BDNs refl.xlsx")
sorrento_remark
# Out:
#           id                                   gid   vessel_name      imo  \
# 0    4505963  97d6856c-4261-4a11-977a-e3891514cde1    MSC REGINA  9202651
# 1    4520265  78343892-8205-44d5-b627-8cdc18b9ef72  MSC MICHAELA  9230488
# 2    4507718  abbe3849-08c6-4054-829c-29332e999624  MSC FABIENNE  9279965
# 3    4521417  0f9b48a5-55cb-4672-ace7-e980dfec4177      MSC LISA  9281279
# 4    4393419  aae25f7a-fe3a-46ff-b49d-6b02d555e268      MSC LISA  9281279
# ..       ...                                   ...           ...      ...
# 367  4545474  25c45230-03f8-44a3-ba35-b97a1799af5a     MSC JIANI  9966934
# 368  4504213  1464f0aa-214f-4d5f-91b7-9aa70687d1ca     MSC JIANI  9966934
# 369  4504203  ee7bd179-e0c7-421f-9d84-0c9e6ae33b15     MSC JIANI  9966934
# 370  4504214  bc0dd51c-5113-4329-a163-b2a8b3e7f4e4     MSC JIANI  9966934
# 371  4531849  8e69c893-5bce-41a4-8680-0544c5d14c37     MSC JIANI  9966934
#
#         voy corrected_date report_date_time report_date_time_offset  \
# ...

# %%
sorrento_remarks = sorrento_remark[sorrento_remark['report_type'] == 'REFL']
sorrento_remarks
# Out:
#           id                                   gid   vessel_name      imo  \
# 0    4505963  97d6856c-4261-4a11-977a-e3891514cde1    MSC REGINA  9202651
# 1    4520265  78343892-8205-44d5-b627-8cdc18b9ef72  MSC MICHAELA  9230488
# 2    4507718  abbe3849-08c6-4054-829c-29332e999624  MSC FABIENNE  9279965
# 3    4521417  0f9b48a5-55cb-4672-ace7-e980dfec4177      MSC LISA  9281279
# 4    4393419  aae25f7a-fe3a-46ff-b49d-6b02d555e268      MSC LISA  9281279
# ..       ...                                   ...           ...      ...
# 367  4545474  25c45230-03f8-44a3-ba35-b97a1799af5a     MSC JIANI  9966934
# 368  4504213  1464f0aa-214f-4d5f-91b7-9aa70687d1ca     MSC JIANI  9966934
# 369  4504203  ee7bd179-e0c7-421f-9d84-0c9e6ae33b15     MSC JIANI  9966934
# 370  4504214  bc0dd51c-5113-4329-a163-b2a8b3e7f4e4     MSC JIANI  9966934
# 371  4531849  8e69c893-5bce-41a4-8680-0544c5d14c37     MSC JIANI  9966934
#
#         voy corrected_date report_date_time report_date_time_offset  \
# ...

# %%
client_sorrento_bdn = pd.read_excel(r"D:\Navalt\MSC\2024\ESI\Group A\JAN24 TO JUN24\CLIENT FILE\SORRENTO MISSING BDNs.xlsx")
client_sorrento_bdn
# Out:
#          id                                   gid    vessel_name      imo  \
# 0   4506956  5970fb57-83b3-4dbf-96d0-27e3f938d11a     MSC ALYSSA  9235050
# 1   4542796  08856b18-12e0-4bb6-add9-0f099539d9e1  MSC AMSTERDAM  9606338
# 2   4502526  62fb10b3-243c-417c-b021-b04f8bdfd5fa      MSC CLARA  9708693
# 3   4491726  40834d6f-1661-4f5b-9480-9cbeafd162d7      MSC DIEGO  9202649
# 4   4519332  fed803bc-bef6-47c1-9d28-4646c189ed74      MSC DIEGO  9202649
# 5   4519350  fda6ce27-7b40-46b9-95a1-82ef4b52efc1      MSC DIEGO  9202649
# 6   4531507  b26641ed-ed17-4ceb-805b-c6140ac30fe8    MSC DILETTA  9897004
# 7   4531505  d86386aa-be02-449a-9211-67b957b99d87    MSC DILETTA  9897004
# 8   4507718  abbe3849-08c6-4054-829c-29332e999624   MSC FABIENNE  9279965
# 9   4397938  27ff2ad1-4e94-4d01-8ced-67f0655e29a4  MSC FRANCESCA  9401116
# 10  4401063  ad99dacc-fba5-46af-a67e-48624a1c2800   MSC ISTANBUL  9606326
# 11  4401060  868f0e5c-a172-4dd0-a7a6-8d37999a7e2e   MSC ISTANBUL  9606326
# ...

# %%
#client_charter_bdn = client_charter_bdn.rename(columns=lambda x: x.lower(), inplace=True)
sorrento_remarks = sorrento_remarks.rename(columns={
    'gid': 'GID',
      'imo'  :     'IMO_No',
    'vessel_name'   :  'VSL',
    'report_date_time'  :'REPORT_DATE_TIME',
    'sulphur_content_pc': 'Sulphur_Content_PC',
    'quantity': 'Quantity',
    'port_delivery': 'Port_Delivery',
    'product_quality': 'Product_Quality',
    'delivery': 'Delivery',
    'bdn': 'BDN'
})

# %%
#client_charter_bdn = client_charter_bdn.rename(columns=lambda x: x.lower(), inplace=True)
client_sorrento_bdn = client_sorrento_bdn.rename(columns={
    'gid': 'GID',
      'imo'  :     'IMO_No',
    'vessel_name'   :  'VSL',
    'report_date_time'  :'REPORT_DATE_TIME',
    'sulphur_content_pc': 'Sulphur_Content_PC',
    'quantity': 'Quantity',
    'port_delivery': 'Port_Delivery',
    'product_quality': 'Product_Quality',
    'delivery': 'Delivery',
    'bdn': 'BDN'
})

# %%
sorrento_remarks
# Out:
#           id                                   GID           VSL   IMO_No  \
# 0    4505963  97d6856c-4261-4a11-977a-e3891514cde1    MSC REGINA  9202651
# 1    4520265  78343892-8205-44d5-b627-8cdc18b9ef72  MSC MICHAELA  9230488
# 2    4507718  abbe3849-08c6-4054-829c-29332e999624  MSC FABIENNE  9279965
# 3    4521417  0f9b48a5-55cb-4672-ace7-e980dfec4177      MSC LISA  9281279
# 4    4393419  aae25f7a-fe3a-46ff-b49d-6b02d555e268      MSC LISA  9281279
# ..       ...                                   ...           ...      ...
# 367  4545474  25c45230-03f8-44a3-ba35-b97a1799af5a     MSC JIANI  9966934
# 368  4504213  1464f0aa-214f-4d5f-91b7-9aa70687d1ca     MSC JIANI  9966934
# 369  4504203  ee7bd179-e0c7-421f-9d84-0c9e6ae33b15     MSC JIANI  9966934
# 370  4504214  bc0dd51c-5113-4329-a163-b2a8b3e7f4e4     MSC JIANI  9966934
# 371  4531849  8e69c893-5bce-41a4-8680-0544c5d14c37     MSC JIANI  9966934
#
#         voy corrected_date REPORT_DATE_TIME report_date_time_offset  \
# ...

# %%
client_sorrento_bdn
# Out:
#          id                                   GID            VSL   IMO_No  \
# 0   4506956  5970fb57-83b3-4dbf-96d0-27e3f938d11a     MSC ALYSSA  9235050
# 1   4542796  08856b18-12e0-4bb6-add9-0f099539d9e1  MSC AMSTERDAM  9606338
# 2   4502526  62fb10b3-243c-417c-b021-b04f8bdfd5fa      MSC CLARA  9708693
# 3   4491726  40834d6f-1661-4f5b-9480-9cbeafd162d7      MSC DIEGO  9202649
# 4   4519332  fed803bc-bef6-47c1-9d28-4646c189ed74      MSC DIEGO  9202649
# 5   4519350  fda6ce27-7b40-46b9-95a1-82ef4b52efc1      MSC DIEGO  9202649
# 6   4531507  b26641ed-ed17-4ceb-805b-c6140ac30fe8    MSC DILETTA  9897004
# 7   4531505  d86386aa-be02-449a-9211-67b957b99d87    MSC DILETTA  9897004
# 8   4507718  abbe3849-08c6-4054-829c-29332e999624   MSC FABIENNE  9279965
# 9   4397938  27ff2ad1-4e94-4d01-8ced-67f0655e29a4  MSC FRANCESCA  9401116
# 10  4401063  ad99dacc-fba5-46af-a67e-48624a1c2800   MSC ISTANBUL  9606326
# 11  4401060  868f0e5c-a172-4dd0-a7a6-8d37999a7e2e   MSC ISTANBUL  9606326
# ...

# %%
value_map = dict(zip(client_sorrento_bdn['GID'], client_sorrento_bdn['Sulphur_Content_PC']))
sorrento_remarks['Sulphur_Content_PC'] = sorrento_remarks['GID'].map(value_map).fillna(sorrento_remarks['Sulphur_Content_PC'])

value_map = dict(zip(client_sorrento_bdn['GID'], client_sorrento_bdn['REPORT_DATE_TIME']))
sorrento_remarks['REPORT_DATE_TIME'] = sorrento_remarks['GID'].map(value_map).fillna(sorrento_remarks['REPORT_DATE_TIME'])

value_map_1 = dict(zip(client_sorrento_bdn['GID'], client_sorrento_bdn['Quantity']))
sorrento_remarks['Quantity'] = sorrento_remarks['GID'].map(value_map_1).fillna(sorrento_remarks['Quantity'])

value_map_1 = dict(zip(client_sorrento_bdn['GID'], client_sorrento_bdn['Product_Quality']))
sorrento_remarks['Product_Quality'] = sorrento_remarks['GID'].map(value_map_1).fillna(sorrento_remarks['Product_Quality'])

value_map_2 = dict(zip(client_sorrento_bdn['GID'], client_sorrento_bdn['Delivery']))
sorrento_remarks['Delivery'] = sorrento_remarks['GID'].map(value_map_2).fillna(sorrento_remarks['Delivery'])
sorrento_remarks
# Out:
#           id                                   GID           VSL   IMO_No  \
# 0    4505963  97d6856c-4261-4a11-977a-e3891514cde1    MSC REGINA  9202651
# 1    4520265  78343892-8205-44d5-b627-8cdc18b9ef72  MSC MICHAELA  9230488
# 2    4507718  abbe3849-08c6-4054-829c-29332e999624  MSC FABIENNE  9279965
# 3    4521417  0f9b48a5-55cb-4672-ace7-e980dfec4177      MSC LISA  9281279
# 4    4393419  aae25f7a-fe3a-46ff-b49d-6b02d555e268      MSC LISA  9281279
# ..       ...                                   ...           ...      ...
# 367  4545474  25c45230-03f8-44a3-ba35-b97a1799af5a     MSC JIANI  9966934
# 368  4504213  1464f0aa-214f-4d5f-91b7-9aa70687d1ca     MSC JIANI  9966934
# 369  4504203  ee7bd179-e0c7-421f-9d84-0c9e6ae33b15     MSC JIANI  9966934
# 370  4504214  bc0dd51c-5113-4329-a163-b2a8b3e7f4e4     MSC JIANI  9966934
# 371  4531849  8e69c893-5bce-41a4-8680-0544c5d14c37     MSC JIANI  9966934
#
#         voy corrected_date REPORT_DATE_TIME report_date_time_offset  \
# ...

# %%
ignored_data_s = client_sorrento_bdn[client_sorrento_bdn['REMARKS']=='IGNORE']
ignored_data_lst_s = ignored_data_s['GID'].unique().tolist()
ignored_data_lst_s
# Out:
# ['620fa7a2-e0ae-46aa-8a98-3e2808b3399d',
#  'eb6c02f7-06c7-49cb-84bf-af0b580ca6eb',
#  '5ea53085-ebe5-416a-8b3c-034b2f712975']

# %%
file_change_refl_vtout_ignored_s = sorrento_remarks[~sorrento_remarks['GID'].isin(ignored_data_lst_s)]
#sorrento_remarks_db = file_change_refl_vtout_ignored_s[['GID','Sulphur_Content_PC','Quantity','Port_Delivery','Product_Quality','Delivery']]
#sorrento_remarks_db

# %%
sr=file_change_refl_vtout_ignored_s[['GID','IMO_No','VSL','REPORT_DATE_TIME','Sulphur_Content_PC','Quantity','Port_Delivery','Product_Quality','Delivery']]

# %%
sr['Sulphur_Content_PC'].isna().sum()
# Out:
# 0

# %%
sorrentonan = sr[sr['Sulphur_Content_PC'].isna()]
sorrentonan
# Out:
# Empty DataFrame
# Columns: [GID, IMO_No, VSL, REPORT_DATE_TIME, Sulphur_Content_PC, Quantity, Port_Delivery, Product_Quality, Delivery]
# Index: []

# %%
sr['BDN'] = 'YES'
sr
# Out:
#                                       GID   IMO_No           VSL  \
# 0    97d6856c-4261-4a11-977a-e3891514cde1  9202651    MSC REGINA
# 1    78343892-8205-44d5-b627-8cdc18b9ef72  9230488  MSC MICHAELA
# 2    abbe3849-08c6-4054-829c-29332e999624  9279965  MSC FABIENNE
# 3    0f9b48a5-55cb-4672-ace7-e980dfec4177  9281279      MSC LISA
# 4    aae25f7a-fe3a-46ff-b49d-6b02d555e268  9281279      MSC LISA
# ..                                    ...      ...           ...
# 367  25c45230-03f8-44a3-ba35-b97a1799af5a  9966934     MSC JIANI
# 368  1464f0aa-214f-4d5f-91b7-9aa70687d1ca  9966934     MSC JIANI
# 369  ee7bd179-e0c7-421f-9d84-0c9e6ae33b15  9966934     MSC JIANI
# 370  bc0dd51c-5113-4329-a163-b2a8b3e7f4e4  9966934     MSC JIANI
# 371  8e69c893-5bce-41a4-8680-0544c5d14c37  9966934     MSC JIANI
#
#     REPORT_DATE_TIME  Sulphur_Content_PC  Quantity Port_Delivery  \
# 0    2024-2-20 22:20              0.0800    80.000         AEAUH
# ...

# %%
# charter_sorrento_db = pd.concat([charter_remarks_db,sorrento_remarks_db])
# charter_sorrento_db

# %%
charter_sorrento_dbs=pd.concat([cr,sr])
charter_sorrento_dbs
# Out:
#                                       GID   IMO_No            VSL  \
# 0    3eacc476-c023-494d-a6ce-a1aa6378218d  9256470    MSC QINGDAO
# 1    d54b3fce-c7e4-4423-bd60-99066cd81cc5  9085534          KOTKA
# 2    a0467399-7302-4cfa-a98e-01ae7ba67a4c  9297589          ALANA
# 3    a030ad08-a899-45f3-8fb8-c828f0d620bc  9247742  MSC BOSPHORUS
# 4    d52d5be1-85ba-4971-99cf-d1cefe281b8c  9256365      MED CESME
# ..                                    ...      ...            ...
# 367  25c45230-03f8-44a3-ba35-b97a1799af5a  9966934      MSC JIANI
# 368  1464f0aa-214f-4d5f-91b7-9aa70687d1ca  9966934      MSC JIANI
# 369  ee7bd179-e0c7-421f-9d84-0c9e6ae33b15  9966934      MSC JIANI
# 370  bc0dd51c-5113-4329-a163-b2a8b3e7f4e4  9966934      MSC JIANI
# 371  8e69c893-5bce-41a4-8680-0544c5d14c37  9966934      MSC JIANI
#
#     REPORT_DATE_TIME  Sulphur_Content_PC  Quantity Port_Delivery  \
# 0     2024-1-1 14:35               0.470  1000.019         ITGOA
# ...

# %% [markdown]
# ### Download the file and give it to software team to update this through 'UPDATE GID CODE (CHARTER)'

# %%
#charter_sorrento_db.to_excel(r"D:\Navalt\MSC\2024\ESI\Group A\JUL23 TO DEC23/OUTPUT FOR DB/charter_sorrento_update_GID.xlsx", index = False)

# %%
charter_sorrento_dbs.to_excel(r"D:\Navalt\MSC\2024\ESI\Group A\JAN24 TO JUN24/OUTPUT FOR DB/charter_sorrento_update_GID.xlsx", index = False)

# %%
#charter_sorrento_db.to_csv(r"D:\Navalt\MSC\2024\ESI\Group A\JUL23 TO DEC23/OUTPUT FOR DB/charter_sorrento_update_GID.csv", index = False)

# %%
charter_sorrento_dbs.to_csv(r"D:\Navalt\MSC\2024\ESI\Group A\JAN24 TO JUN24/OUTPUT FOR DB/charter_sorrento_update_GID.csv", index = False)

# %% [markdown]
# # MSCSMCY

# %%
msc_remark = pd.read_excel(r"D:\Navalt\MSC\2024\ESI\Group A\JAN24 TO JUN24\OUTPUT/MSCSMCY MISSING BDNs refl.xlsx")
msc_remark
# Out:
#            id      imo          vessel id_vessel      gid  voyage  \
# 0     5732600  8521402   MSC ANNAMARIA      ANMA  5189583     NaN
# 1     5732601  8521402   MSC ANNAMARIA      ANMA  5189587     NaN
# 2     5760028  9702089        MSC VITA      VITA  5189807     NaN
# 3     5753589  9330226   MSC ABIGAIL F      ABIG  5190958     NaN
# 4     5748708  9292175  MSC SHANELLE V      SHNL  5190148     NaN
# ...       ...      ...             ...       ...      ...     ...
# 2303  6311513  9244881    MSC ARUSHI R      ARUS  5532057     NaN
# 2304  6304722  9162643         MSC LEA       LEA  5530815     NaN
# 2305  6299544  8512906       MSC ADELE      ADEL  5533194     NaN
# 2306  6321378  9360271    MSC CAPE III      CAPE  5531232     NaN
# 2307  6311514  9244881    MSC ARUSHI R      ARUS  5532055     NaN
#
#            corrected_date     report_date_time report_date_time_offset  \
# 0     2023-12-31 21:25:00  2024-01-01 00:25:00               UTC-03:00
# ...

# %%
msc_remarks = msc_remark[msc_remark['report_type'] == 'REFL']
msc_remarks
# Out:
#            id      imo          vessel id_vessel      gid  voyage  \
# 0     5732600  8521402   MSC ANNAMARIA      ANMA  5189583     NaN
# 1     5732601  8521402   MSC ANNAMARIA      ANMA  5189587     NaN
# 2     5760028  9702089        MSC VITA      VITA  5189807     NaN
# 3     5753589  9330226   MSC ABIGAIL F      ABIG  5190958     NaN
# 4     5748708  9292175  MSC SHANELLE V      SHNL  5190148     NaN
# ...       ...      ...             ...       ...      ...     ...
# 2303  6311513  9244881    MSC ARUSHI R      ARUS  5532057     NaN
# 2304  6304722  9162643         MSC LEA       LEA  5530815     NaN
# 2305  6299544  8512906       MSC ADELE      ADEL  5533194     NaN
# 2306  6321378  9360271    MSC CAPE III      CAPE  5531232     NaN
# 2307  6311514  9244881    MSC ARUSHI R      ARUS  5532055     NaN
#
#            corrected_date     report_date_time report_date_time_offset  \
# 0     2023-12-31 21:25:00  2024-01-01 00:25:00               UTC-03:00
# ...

# %%
client_msc_bdn = pd.read_excel(r"D:\Navalt\MSC\2024\ESI\Group A\JAN24 TO JUN24\CLIENT FILE/MSCSMCY MISSING BDNs.xlsx")
client_msc_bdn
# Out:
#           id      imo         vessel id_vessel  \
# 0    5740180  9210086        MSC ABY       ABY
# 1    5754557  9344708       MSC ADYA       NaN
# 2    5764561  9932050       MSC ADYA       NaN
# 3    5734485  9060649       MSC ADYA       NaN
# 4    5734429  9057173       MSC ADYA       NaN
# ..       ...      ...            ...       ...
# 224  6304154  9154191  WEC MONDRIAAN      WECM
# 225  6321080  9354363  WEC MONDRIAAN      WECM
# 226  5750179  9301990  WEC MONDRIAAN      WECM
# 227  5778373  9253038   WEC VAN RIJN      WVRN
# 228  5781101  9293167   WEC VAN RIJN      WVRN
#
#                                       gid  voyage       corrected_date  \
# 0                                 5218514     NaN  2024-01-11 23:40:00
# 1    cab0d3d6-2059-486d-84ac-79592a1d3343     NaN  2024-06-01 00:00:00
# 2    4c78b1d1-fd7e-4a3b-a795-0add2d885bca     NaN  2024-06-01 00:00:00
# 3    8bddafa1-5a61-41ef-83d8-2ea47d3ff073     NaN  2024-06-01 00:00:00
# ...

# %%
#client_charter_bdn = client_charter_bdn.rename(columns=lambda x: x.lower(), inplace=True)
client_msc_bdn = client_msc_bdn.rename(columns={
    'gid': 'GID',
      'imo'  :     'IMO_No',
    'vessel'   :  'VSL',
    'report_date_time'  :'REPORT_DATE_TIME',
    'sulphur_content_pc': 'Sulphur_Content_PC',
    'quantity': 'Quantity',
    'port_delivery': 'Port_Delivery',
    'product_quality': 'Product_Quality',
    'delivery': 'Delivery',
    'bdn': 'BDN'
})

# %%
#client_charter_bdn = client_charter_bdn.rename(columns=lambda x: x.lower(), inplace=True)
msc_remarks = msc_remarks.rename(columns={
    'gid': 'GID',
      'imo'  :     'IMO_No',
    'vessel'   :  'VSL',
    'report_date_time'  :'REPORT_DATE_TIME',
    'sulphur_content_pc': 'Sulphur_Content_PC',
    'quantity': 'Quantity',
    'port_delivery': 'Port_Delivery',
    'product_quality': 'Product_Quality',
    'delivery': 'Delivery',
    'bdn': 'BDN'
})

# %%
msc_remarks
# Out:
#            id   IMO_No             VSL id_vessel      GID  voyage  \
# 0     5732600  8521402   MSC ANNAMARIA      ANMA  5189583     NaN
# 1     5732601  8521402   MSC ANNAMARIA      ANMA  5189587     NaN
# 2     5760028  9702089        MSC VITA      VITA  5189807     NaN
# 3     5753589  9330226   MSC ABIGAIL F      ABIG  5190958     NaN
# 4     5748708  9292175  MSC SHANELLE V      SHNL  5190148     NaN
# ...       ...      ...             ...       ...      ...     ...
# 2303  6311513  9244881    MSC ARUSHI R      ARUS  5532057     NaN
# 2304  6304722  9162643         MSC LEA       LEA  5530815     NaN
# 2305  6299544  8512906       MSC ADELE      ADEL  5533194     NaN
# 2306  6321378  9360271    MSC CAPE III      CAPE  5531232     NaN
# 2307  6311514  9244881    MSC ARUSHI R      ARUS  5532055     NaN
#
#            corrected_date     REPORT_DATE_TIME report_date_time_offset  \
# 0     2023-12-31 21:25:00  2024-01-01 00:25:00               UTC-03:00
# ...

# %%
client_msc_bdn
# Out:
#           id   IMO_No            VSL id_vessel  \
# 0    5740180  9210086        MSC ABY       ABY
# 1    5754557  9344708       MSC ADYA       NaN
# 2    5764561  9932050       MSC ADYA       NaN
# 3    5734485  9060649       MSC ADYA       NaN
# 4    5734429  9057173       MSC ADYA       NaN
# ..       ...      ...            ...       ...
# 224  6304154  9154191  WEC MONDRIAAN      WECM
# 225  6321080  9354363  WEC MONDRIAAN      WECM
# 226  5750179  9301990  WEC MONDRIAAN      WECM
# 227  5778373  9253038   WEC VAN RIJN      WVRN
# 228  5781101  9293167   WEC VAN RIJN      WVRN
#
#                                       GID  voyage       corrected_date  \
# 0                                 5218514     NaN  2024-01-11 23:40:00
# 1    cab0d3d6-2059-486d-84ac-79592a1d3343     NaN  2024-06-01 00:00:00
# 2    4c78b1d1-fd7e-4a3b-a795-0add2d885bca     NaN  2024-06-01 00:00:00
# 3    8bddafa1-5a61-41ef-83d8-2ea47d3ff073     NaN  2024-06-01 00:00:00
# ...

# %%
value_map = dict(zip(client_msc_bdn['GID'], client_msc_bdn['Sulphur_Content_PC']))
msc_remarks['Sulphur_Content_PC'] = msc_remarks['GID'].map(value_map).fillna(msc_remarks['Sulphur_Content_PC'])

value_map = dict(zip(client_msc_bdn['GID'], client_msc_bdn['REPORT_DATE_TIME']))
msc_remarks['REPORT_DATE_TIME'] = msc_remarks['GID'].map(value_map).fillna(msc_remarks['REPORT_DATE_TIME'])


value_map_1 = dict(zip(client_msc_bdn['GID'], client_msc_bdn['Quantity']))
msc_remarks['Quantity'] = msc_remarks['GID'].map(value_map_1).fillna(msc_remarks['Quantity'])

value_map_1 = dict(zip(client_msc_bdn['GID'], client_msc_bdn['Product_Quality']))
msc_remarks['Product_Quality'] = msc_remarks['GID'].map(value_map_1).fillna(msc_remarks['Product_Quality'])

value_map_2 = dict(zip(client_msc_bdn['GID'], client_msc_bdn['Delivery']))
msc_remarks['Delivery'] = msc_remarks['GID'].map(value_map_2).fillna(msc_remarks['Delivery'])
msc_remarks
# Out:
#            id   IMO_No             VSL id_vessel      GID  voyage  \
# 0     5732600  8521402   MSC ANNAMARIA      ANMA  5189583     NaN
# 1     5732601  8521402   MSC ANNAMARIA      ANMA  5189587     NaN
# 2     5760028  9702089        MSC VITA      VITA  5189807     NaN
# 3     5753589  9330226   MSC ABIGAIL F      ABIG  5190958     NaN
# 4     5748708  9292175  MSC SHANELLE V      SHNL  5190148     NaN
# ...       ...      ...             ...       ...      ...     ...
# 2303  6311513  9244881    MSC ARUSHI R      ARUS  5532057     NaN
# 2304  6304722  9162643         MSC LEA       LEA  5530815     NaN
# 2305  6299544  8512906       MSC ADELE      ADEL  5533194     NaN
# 2306  6321378  9360271    MSC CAPE III      CAPE  5531232     NaN
# 2307  6311514  9244881    MSC ARUSHI R      ARUS  5532055     NaN
#
#            corrected_date     REPORT_DATE_TIME report_date_time_offset  \
# 0     2023-12-31 21:25:00  2024-01-01 00:25:00               UTC-03:00
# ...

# %%
msc_remarks['Delivery'].value_counts()
# Out:
# BRBRB202400009063      8
# 282024001035           4
# BDN DATE 26.02.2024    4
# BDN DATE 23.06.2024    3
# BDN DATE 18.01.2024    3
#                       ..
# FLNGVENOSA-2024-016    1
# AE190845               1
# 12711381               1
# 16040                  1
# BDN DATE 28.06.2024    1
# Name: Delivery, Length: 181, dtype: int64

# %%
msc_remarks
# Out:
#            id   IMO_No             VSL id_vessel      GID  voyage  \
# 0     5732600  8521402   MSC ANNAMARIA      ANMA  5189583     NaN
# 1     5732601  8521402   MSC ANNAMARIA      ANMA  5189587     NaN
# 2     5760028  9702089        MSC VITA      VITA  5189807     NaN
# 3     5753589  9330226   MSC ABIGAIL F      ABIG  5190958     NaN
# 4     5748708  9292175  MSC SHANELLE V      SHNL  5190148     NaN
# ...       ...      ...             ...       ...      ...     ...
# 2303  6311513  9244881    MSC ARUSHI R      ARUS  5532057     NaN
# 2304  6304722  9162643         MSC LEA       LEA  5530815     NaN
# 2305  6299544  8512906       MSC ADELE      ADEL  5533194     NaN
# 2306  6321378  9360271    MSC CAPE III      CAPE  5531232     NaN
# 2307  6311514  9244881    MSC ARUSHI R      ARUS  5532055     NaN
#
#            corrected_date     REPORT_DATE_TIME report_date_time_offset  \
# 0     2023-12-31 21:25:00  2024-01-01 00:25:00               UTC-03:00
# ...

# %%
msc_remarks.to_csv("msc_remarks.csv")

# %%
msc_remarks_ignore = client_msc_bdn[(client_msc_bdn['REMARKS'] == 'IGNORE') | (client_msc_bdn['REMARKS'] == 'Debunker ignore')]
msc_remarks_ignore
# Out:
#           id   IMO_No              VSL id_vessel  \
# 58   5782291  9301550        MSC CAPRI      CAPR
# 136  6255954  9354363  MSC MARIAGRAZIA       NaN
# 138  6242665  9226932  MSC MARIAGRAZIA       NaN
# 142  6339573  9946879        MSC MARIE       NaN
# 144  6339191  9360764        MSC MARIE       NaN
#
#                                       GID  voyage       corrected_date  \
# 58                                5279523     NaN  2024-02-17 20:30:00
# 136  1ef7d4a1-15a4-4ece-9f66-00e7ab03b10e     NaN  2024-05-31 00:00:00
# 138  b6073898-97ba-47c1-b21d-064a4007273f     NaN  2024-05-31 00:00:00
# 142  b04b925d-5bf1-43a2-ad7b-f519fedaf912     NaN  2024-05-31 00:00:00
# 144  ce795b15-0578-4a3f-b5eb-742b24ff80f9     NaN  2024-05-31 00:00:00
#
#         REPORT_DATE_TIME report_date_time_offset report_type  ...  \
# 58   2024-02-17 18:30:00               UTC+02:00        REFL  ...
# 136  2024-05-25 19:36:00               UTC-05-26        REFL  ...
# ...

# %%
gid = msc_remarks_ignore['GID'].unique().tolist()
gid
# Out:
# [5279523,
#  '1ef7d4a1-15a4-4ece-9f66-00e7ab03b10e',
#  'b6073898-97ba-47c1-b21d-064a4007273f',
#  'b04b925d-5bf1-43a2-ad7b-f519fedaf912',
#  'ce795b15-0578-4a3f-b5eb-742b24ff80f9']

# %%
msc_remarks_ok = msc_remarks[~msc_remarks['GID'].isin(gid)]
msc_remarks_ok
# Out:
#            id   IMO_No             VSL id_vessel      GID  voyage  \
# 0     5732600  8521402   MSC ANNAMARIA      ANMA  5189583     NaN
# 1     5732601  8521402   MSC ANNAMARIA      ANMA  5189587     NaN
# 2     5760028  9702089        MSC VITA      VITA  5189807     NaN
# 3     5753589  9330226   MSC ABIGAIL F      ABIG  5190958     NaN
# 4     5748708  9292175  MSC SHANELLE V      SHNL  5190148     NaN
# ...       ...      ...             ...       ...      ...     ...
# 2303  6311513  9244881    MSC ARUSHI R      ARUS  5532057     NaN
# 2304  6304722  9162643         MSC LEA       LEA  5530815     NaN
# 2305  6299544  8512906       MSC ADELE      ADEL  5533194     NaN
# 2306  6321378  9360271    MSC CAPE III      CAPE  5531232     NaN
# 2307  6311514  9244881    MSC ARUSHI R      ARUS  5532055     NaN
#
#            corrected_date     REPORT_DATE_TIME report_date_time_offset  \
# 0     2023-12-31 21:25:00  2024-01-01 00:25:00               UTC-03:00
# ...

# %%
# msc_remarks_db = msc_remarks_ok[['GID','Sulphur_Content_PC','Quantity','Port_Delivery','Product_Quality','Delivery']]
# msc_remarks_db

# %%
ms=msc_remarks_ok[['GID','IMO_No','VSL','REPORT_DATE_TIME','Sulphur_Content_PC','Quantity','Port_Delivery','Product_Quality','Delivery']]

# %%
ms['Sulphur_Content_PC'].isna().sum()
# Out:
# 0

# %%
nan = ms[ms['Sulphur_Content_PC'].isna()]
nan
# Out:
# Empty DataFrame
# Columns: [GID, IMO_No, VSL, REPORT_DATE_TIME, Sulphur_Content_PC, Quantity, Port_Delivery, Product_Quality, Delivery]
# Index: []

# %%
msc_remarks_db_final = ms.dropna(subset=['Sulphur_Content_PC']).reset_index(drop=True)
msc_remarks_db_final
# Out:
#           GID   IMO_No             VSL     REPORT_DATE_TIME  \
# 0     5189583  8521402   MSC ANNAMARIA  2024-01-01 00:25:00
# 1     5189587  8521402   MSC ANNAMARIA  2024-01-01 00:35:00
# 2     5189807  9702089        MSC VITA  2024-01-01 10:00:00
# 3     5190958  9330226   MSC ABIGAIL F  2024-01-01 12:14:00
# 4     5190148  9292175  MSC SHANELLE V  2024-01-01 13:15:00
# ...       ...      ...             ...                  ...
# 2298  5532057  9244881    MSC ARUSHI R  2024-06-30 13:39:00
# 2299  5530815  9162643         MSC LEA  2024-06-30 14:30:00
# 2300  5533194  8512906       MSC ADELE  2024-06-30 16:36:00
# 2301  5531232  9360271    MSC CAPE III  2024-06-30 19:48:00
# 2302  5532055  9244881    MSC ARUSHI R  2024-06-30 20:30:00
#
#       Sulphur_Content_PC  Quantity Port_Delivery  Product_Quality Delivery
# 0                 0.4200   100.253         BRBEL              NaN      NaN
# 1                 0.0100    50.028         BRBEL              NaN      NaN
# ...

# %%
msc_remarks_db_final['BDN'] = 'YES'
msc_remarks_db_final
# Out:
#           GID   IMO_No             VSL     REPORT_DATE_TIME  \
# 0     5189583  8521402   MSC ANNAMARIA  2024-01-01 00:25:00
# 1     5189587  8521402   MSC ANNAMARIA  2024-01-01 00:35:00
# 2     5189807  9702089        MSC VITA  2024-01-01 10:00:00
# 3     5190958  9330226   MSC ABIGAIL F  2024-01-01 12:14:00
# 4     5190148  9292175  MSC SHANELLE V  2024-01-01 13:15:00
# ...       ...      ...             ...                  ...
# 2298  5532057  9244881    MSC ARUSHI R  2024-06-30 13:39:00
# 2299  5530815  9162643         MSC LEA  2024-06-30 14:30:00
# 2300  5533194  8512906       MSC ADELE  2024-06-30 16:36:00
# 2301  5531232  9360271    MSC CAPE III  2024-06-30 19:48:00
# 2302  5532055  9244881    MSC ARUSHI R  2024-06-30 20:30:00
#
#       Sulphur_Content_PC  Quantity Port_Delivery  Product_Quality Delivery  \
# 0                 0.4200   100.253         BRBEL              NaN      NaN
# 1                 0.0100    50.028         BRBEL              NaN      NaN
# ...

# %% [markdown]
# ### Download the file and give the software team to update this through 'UPDATE GID CODE (NOONDATA)'

# %%
#msc_remarks_db_final.to_excel(r"D:\Navalt\MSC\2024\ESI\Group A\JUL23 TO DEC23/OUTPUT FOR DB/MSCSMCY_update_GID.xlsx", index = False)

# %%
#msc_remarks_db_final.to_csv(r"D:\Navalt\MSC\2024\ESI\Group A\JUL23 TO DEC23/OUTPUT FOR DB/MSCSMCY_update_GID.csv", index = False)

# %%
msc_remarks_db_final.to_excel(r"D:\Navalt\MSC\2024\ESI\Group A\JAN24 TO JUN24/OUTPUT FOR DB/MSCSMCY_update_GID.xlsx", index = False)

# %%
msc_remarks_db_final.to_csv(r"D:\Navalt\MSC\2024\ESI\Group A\JAN24 TO JUN24/OUTPUT FOR DB/MSCSMCY_update_GID.csv", index = False)
