# %%
import pandas as pd

# %%
esi = pd.read_excel(r"D:\Navalt\MSC\2024\ESI\Group A\JUL23 TO DEC23\CLIENT FILE\ESI Vessels current window.xlsx")
esi
# Out:
#          IMO    Fleet       Group              Vessel Scrubber     GT  \
# 0    9297589  CHARTER         NaN               ALANA       No  11662
# 1    9625970        9  ANASTASIA            ANASTASIA       No  51168
# 2    9342695  CHARTER         NaN       AS California       No  28340
# 3    9314947  CHARTER         NaN         AS CAMELLIA      Yes  28927
# 4    9321897  CHARTER         NaN            AS Nadia       No  38332
# ..       ...      ...         ...                 ...      ...    ...
# 422  9315018        1        WEC4        WEC DE HOOGH       No  11662
# 423  9326964        1         WEC      WEC FRANS HALS      Yes   9990
# 424  9354363        1         WEC       WEC MONDRIAAN       No   9981
# 425  9315006        1        WEC4        WEC VAN RIJN       No  11662
# 426  9252993  CHARTER         NaN  Zhu Cheng Xin Zhou       No  25703
#
#      Year of Keel laid
# 0                 2002
# 1                 2012
# 2                 2007
# 3                 2005
# ...

# %%
esi_sorrento = esi[(esi['Fleet'] == 'SORRENTO') & (esi['Scrubber'] == 'Yes')]
esi_sorrento
# Out:
#          IMO     Fleet Group                 Vessel Scrubber      GT  \
# 59   9839480  SORRENTO   NaN              MSC AMBRA      Yes  232618
# 91   9399014  SORRENTO   NaN           MSC BEATRICE      Yes  151559
# 115  9930040  SORRENTO   NaN  MSC CELESTINO MARESCA      Yes  236078
# 120  9708693  SORRENTO   NaN              MSC CLARA      Yes  192237
# 136  9897004  SORRENTO   NaN            MSC DILETTA      Yes  228786
# 166  9401116  SORRENTO   NaN          MSC FRANCESCA      Yes  131771
# 195  9398371  SORRENTO   NaN              MSC IVANA      Yes  131771
# 211  9399026  SORRENTO   NaN             MSC KALINA      Yes  151559
# 214  9467457  SORRENTO   NaN              MSC KATIE      Yes  140096
# 228  9225665  SORRENTO   NaN              MSC LAURA      Yes   75590
# 240  9230490  SORRENTO   NaN            MSC LORETTA      Yes   73819
# 265  9708679  SORRENTO   NaN               MSC MAYA      Yes  192237
# 267  9226918  SORRENTO   NaN            MSC MELISSA      Yes   73819
# ...

# %%
charter = pd.read_excel(r"D:\Navalt\MSC\2023\Weekly Data\CHARTER\raw_data_charter\raw_data_charter_41-52.xlsx")
charter
# Out:
#                                         GID                 VSL   IMO No  \
# 0      e5df09ef-2ee5-4b90-ba50-2203166ad051     AGIOS DIMITRIOS  9349605
# 1      01a10f31-cb8a-4197-8325-316e4a99db49     AGIOS DIMITRIOS  9349605
# 2      6e473f22-a63f-438b-b75b-bb74ac5d944e     AGIOS DIMITRIOS  9349605
# 3      a8369fa3-38a7-433e-bade-dd6f19229ce6     AGIOS DIMITRIOS  9349605
# 4      f0fb079f-951e-49b8-a53c-ea79734d5d53     AGIOS DIMITRIOS  9349605
# ...                                     ...                 ...      ...
# 10079  a7a3a4b9-a1c4-4b62-a657-c89fbedb1d5f  ZHU CHENG XIN ZHOU  9252993
# 10080  d5169069-f7d5-46f0-9876-2ae5dc423a59  ZHU CHENG XIN ZHOU  9252993
# 10081  d88d338a-e3e1-4539-84f2-22b96930cb57  ZHU CHENG XIN ZHOU  9252993
# 10082  86218b81-26be-46d6-8bf5-f5b3ac366913  ZHU CHENG XIN ZHOU  9252993
# 10083  25d70868-0a7a-48d5-8579-a8720d2cb9a4  ZHU CHENG XIN ZHOU  9252993
#
#           VOY Corrected Date    REPORT DATE TIME REPORT DATE TIME Offset  \
# ...

# %%
esi_sorrento_lst = esi_sorrento['IMO'].to_list()
esi_sorrento_lst
# Out:
# [9839480,
#  9399014,
#  9930040,
#  9708693,
#  9897004,
#  9401116,
#  9398371,
#  9399026,
#  9467457,
#  9225665,
#  9230490,
#  9708679,
#  9226918,
#  9230488,
#  9897016,
#  9955789,
#  9703291,
#  9754965,
#  9404663,
#  9279989,
#  9708681,
#  9703318]

# %%
sorrentodata_final = charter[charter['IMO No'].isin(esi_sorrento_lst)]
pd.set_option('display.max_columns', None)  
sorrentodata_final
# Out:
#                                        GID        VSL   IMO No     VOY  \
# 3969  fa889360-fc62-4bab-b312-18f9aa43bba0  MSC AMBRA  9839480  QG350E
# 3970  d3e0069e-3b0b-459b-9f83-466fef229e09  MSC AMBRA  9839480  QG350E
# 3971  fabd45c8-4ddc-4fca-bd98-91625f2764e4  MSC AMBRA  9839480  QG350E
# 3972  66664352-4eb9-4a6a-a3e7-3fcd675cb8a2  MSC AMBRA  9839480  QG350E
# 3973  70dd500b-7b1f-424f-8d30-623d17e3bd2a  MSC AMBRA  9839480  QG350E
# ...                                    ...        ...      ...     ...
# 9513  afc2bc7d-0a23-40e4-bcbd-498dd483793e    MSC ZOE  9703318  FT348W
# 9514  6df76a90-641b-4965-9f3c-08269cc972c0    MSC ZOE  9703318  FT348W
# 9515  436d1d69-5440-46fb-a5bc-b33dcacfc8f9    MSC ZOE  9703318  FT348W
# 9516  b65991f8-796f-4209-a0a9-3ff98b2c7a6e    MSC ZOE  9703318  FT348W
# 9517  9e3c9133-d25b-463d-a7f8-dc54df4d99c6    MSC ZOE  9703318  FT348W
#
#      Corrected Date    REPORT DATE TIME REPORT DATE TIME Offset Report Type  \
# ...

# %%
pd.set_option('display.max_columns', None)  
sorrentodata_final
# Out:
#                                        GID        VSL   IMO No     VOY  \
# 3969  fa889360-fc62-4bab-b312-18f9aa43bba0  MSC AMBRA  9839480  QG350E
# 3970  d3e0069e-3b0b-459b-9f83-466fef229e09  MSC AMBRA  9839480  QG350E
# 3971  fabd45c8-4ddc-4fca-bd98-91625f2764e4  MSC AMBRA  9839480  QG350E
# 3972  66664352-4eb9-4a6a-a3e7-3fcd675cb8a2  MSC AMBRA  9839480  QG350E
# 3973  70dd500b-7b1f-424f-8d30-623d17e3bd2a  MSC AMBRA  9839480  QG350E
# ...                                    ...        ...      ...     ...
# 9513  afc2bc7d-0a23-40e4-bcbd-498dd483793e    MSC ZOE  9703318  FT348W
# 9514  6df76a90-641b-4965-9f3c-08269cc972c0    MSC ZOE  9703318  FT348W
# 9515  436d1d69-5440-46fb-a5bc-b33dcacfc8f9    MSC ZOE  9703318  FT348W
# 9516  b65991f8-796f-4209-a0a9-3ff98b2c7a6e    MSC ZOE  9703318  FT348W
# 9517  9e3c9133-d25b-463d-a7f8-dc54df4d99c6    MSC ZOE  9703318  FT348W
#
#      Corrected Date    REPORT DATE TIME REPORT DATE TIME Offset Report Type  \
# ...

# %%
imo_counts = sorrentodata_final['IMO No'].value_counts()
imo_counts
# Out:
# 9930040    64
# 9398371    57
# 9225665    50
# 9754965    46
# 9404663    44
# 9708679    43
# 9279989    41
# 9226918    37
# 9230488    36
# 9897016    27
# 9467457    26
# 9399014    26
# 9399026    20
# 9708693    20
# 9703291    17
# 9230490    16
# 9708681    10
# 9839480    10
# 9401116    10
# 9897004    10
# 9703318    10
# Name: IMO No, dtype: int64

# %%
sorrentodata_final['IMO No'].nunique()
# Out:
# 21

# %%
scrubber = sorrentodata_final.loc[(sorrentodata_final['Report Type'] != "REFL") & (sorrentodata_final['SO2 CO2 RATIO'].notnull())]

scrubber_2 = sorrentodata_final.loc[(sorrentodata_final['SO2 CO2 RATIO'].astype(float) != 0.0) & (sorrentodata_final['SO2 CO2 RATIO'].astype(float) <= 12.7)]

# %%
scrubber
# Out:
#                                        GID        VSL   IMO No     VOY  \
# 3969  fa889360-fc62-4bab-b312-18f9aa43bba0  MSC AMBRA  9839480  QG350E
# 3970  d3e0069e-3b0b-459b-9f83-466fef229e09  MSC AMBRA  9839480  QG350E
# 3971  fabd45c8-4ddc-4fca-bd98-91625f2764e4  MSC AMBRA  9839480  QG350E
# 3972  66664352-4eb9-4a6a-a3e7-3fcd675cb8a2  MSC AMBRA  9839480  QG350E
# 3973  70dd500b-7b1f-424f-8d30-623d17e3bd2a  MSC AMBRA  9839480  QG350E
# ...                                    ...        ...      ...     ...
# 9513  afc2bc7d-0a23-40e4-bcbd-498dd483793e    MSC ZOE  9703318  FT348W
# 9514  6df76a90-641b-4965-9f3c-08269cc972c0    MSC ZOE  9703318  FT348W
# 9515  436d1d69-5440-46fb-a5bc-b33dcacfc8f9    MSC ZOE  9703318  FT348W
# 9516  b65991f8-796f-4209-a0a9-3ff98b2c7a6e    MSC ZOE  9703318  FT348W
# 9517  9e3c9133-d25b-463d-a7f8-dc54df4d99c6    MSC ZOE  9703318  FT348W
#
#      Corrected Date    REPORT DATE TIME REPORT DATE TIME Offset Report Type  \
# ...

# %%
scrubber
# Out:
#                                        GID        VSL   IMO No     VOY  \
# 3969  fa889360-fc62-4bab-b312-18f9aa43bba0  MSC AMBRA  9839480  QG350E
# 3970  d3e0069e-3b0b-459b-9f83-466fef229e09  MSC AMBRA  9839480  QG350E
# 3971  fabd45c8-4ddc-4fca-bd98-91625f2764e4  MSC AMBRA  9839480  QG350E
# 3972  66664352-4eb9-4a6a-a3e7-3fcd675cb8a2  MSC AMBRA  9839480  QG350E
# 3973  70dd500b-7b1f-424f-8d30-623d17e3bd2a  MSC AMBRA  9839480  QG350E
# ...                                    ...        ...      ...     ...
# 9513  afc2bc7d-0a23-40e4-bcbd-498dd483793e    MSC ZOE  9703318  FT348W
# 9514  6df76a90-641b-4965-9f3c-08269cc972c0    MSC ZOE  9703318  FT348W
# 9515  436d1d69-5440-46fb-a5bc-b33dcacfc8f9    MSC ZOE  9703318  FT348W
# 9516  b65991f8-796f-4209-a0a9-3ff98b2c7a6e    MSC ZOE  9703318  FT348W
# 9517  9e3c9133-d25b-463d-a7f8-dc54df4d99c6    MSC ZOE  9703318  FT348W
#
#      Corrected Date    REPORT DATE TIME REPORT DATE TIME Offset Report Type  \
# ...

# %%
print(refl_sorrento['SO2 CO2 RATIO'])
# Out:
# 4974    NaN
# 4975    NaN
# 4976    NaN
# 4977    NaN
# 5114    NaN
# 6653    NaN
# 7674    2.5
# 7882    NaN
# 7883    NaN
# 8104    NaN
# Name: SO2 CO2 RATIO, dtype: float64
