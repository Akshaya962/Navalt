# %%
# !pip install requests beautifulsoup4
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import requests
from bs4 import BeautifulSoup

url = "https://clarity.microsoft.com/projects/view/m46eh0tli0/dashboard?date=Last%203%20days"

response = requests.get(url)

soup= BeautifulSoup(response.text, 'html')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# ...

# %%
soup.find_all('div')
# Out:
# [<div id="cookie-banner"></div>,
#  <div id="clarity-app-root" style="display: flex; min-width: 100%; min-height: 100%;"></div>]

# %%
<div class="dashboard_usersInfoLabel__1fFNK dashboard_label__6chaC shared_darkGrayFontBold__bK3Bp shared_verticalFlex__rAS0M shared_flex__bW95Y"><div>Live users</div><div class="dashboard_usersInfoSubtitle__DiYOz dashboard_italicSubtitle__c4hmJ dashboard_subtitle__HFgws shared_lightGrayFont__IAlG3">1.0 min ago</div></div>
# Out:
#   Input In [4]
#     <div class="dashboard_usersInfoLabel__1fFNK dashboard_label__6chaC shared_darkGrayFontBold__bK3Bp shared_verticalFlex__rAS0M shared_flex__bW95Y"><div>Live users</div><div class="dashboard_usersInfoSubtitle__DiYOz dashboard_italicSubtitle__c4hmJ dashboard_subtitle__HFgws shared_lightGrayFont__IAlG3">1.0 min ago</div></div>
#     ^
# SyntaxError: invalid syntax

# %%
html_content = '<div class="dashboard_usersInfoLabel__1fFNK dashboard_label__6chaC shared_darkGrayFontBold__bK3Bp shared_verticalFlex__rAS0M shared_flex__bW95Y"><div>Live users</div><div class="dashboard_usersInfoSubtitle__DiYOz dashboard_italicSubtitle__c4hmJ dashboard_subtitle__HFgws shared_lightGrayFont__IAlG3">1.0 min ago</div></div>'

soup = BeautifulSoup(html_content, 'html.parser')

dashboard_info_div = soup.find('div', class_='dashboard_usersInfoLabel__1fFNK')

if dashboard_info_div:
    live_users_text = dashboard_info_div.find_all('div')[0].text.strip()
    last_updated_text = dashboard_info_div.find_all('div')[1].text.strip()
    
    print("Live users:", live_users_text)
    print("Last updated:", last_updated_text)
else:
    print("Div not found")
# Out:
# Live users: Live users
# Last updated: 1.0 min ago

# %%
<div class="dashboard_usersInfoLabel__1fFNK dashboard_label__6chaC shared_darkGrayFontBold__bK3Bp shared_verticalFlex__rAS0M shared_flex__bW95Y"><div>Unique users</div><div class="dashboard_usersInfoSubtitle__DiYOz dashboard_italicSubtitle__c4hmJ dashboard_subtitle__HFgws shared_lightGrayFont__IAlG3"></div></div>

# %%
<div class="dashboard_usersNumber__0oR2P dashboard_loud__ynA6u shared_darkBlueFont__owkq3" data-testid="distinctUsers">23</div>

# %%
from bs4 import BeautifulSoup

html_content = '<div class="dashboard_usersInfoLabel__1fFNK dashboard_label__6chaC shared_darkGrayFontBold__bK3Bp shared_verticalFlex__rAS0M shared_flex__bW95Y"><div>Unique users</div><div class="dashboard_usersInfoSubtitle__DiYOz dashboard_italicSubtitle__c4hmJ dashboard_subtitle__HFgws shared_lightGrayFont__IAlG3"></div></div>'
html_content_value ='<div class="dashboard_usersNumber__0oR2P dashboard_loud__ynA6u shared_darkBlueFont__owkq3" data-testid="distinctUsers">23</div>'

soup = BeautifulSoup(html_content, 'html.parser')

dashboard_info_div = soup.find('div', class_='dashboard_usersInfoLabel__1fFNK')

if dashboard_info_div:
    unique_users_header = dashboard_info_div.find('div').text.strip()
else:
    unique_users_header = "Header not found"

soup_value = BeautifulSoup(html_content_value, 'html.parser')

unique_users_value_div = soup_value.find('div', class_='dashboard_usersNumber__0oR2P')

if unique_users_value_div:
    value = unique_users_value_div.text.strip()
else:
    value = "Value not found"

print(unique_users_header)
print(value)
# Out:
# Unique users
# 23

# %%
<div class="dashboard_legend__Z6dO5"><div class=""><div class="dashboard_legendColor__L+rL3" style="background: rgb(237, 54, 255);"></div></div><div class="dashboard_legendLabel__C-C9u " title="Sessions with new users">Sessions with new users</div><div class="">0%</div><div class="">0</div><div class=""><button type="button" data-testid="recording button Sessions with new users" class="ms-Button ms-Button--icon root-104" aria-label="Set as filter and go to recordings" data-is-focusable="true"><span class="ms-Button-flexContainer flexContainer-105" data-automationid="splitbuttonprimary"><i data-icon-name="cameraFilledIn" aria-hidden="true" class="ms-Icon root-89 ms-Button-icon icon-107"><svg width="15" height="12" viewBox="0 0 15 12" fill="none"><path d="M3 0.666656C1.61929 0.666656 0.5 1.78594 0.5 3.16666V9.16666C0.5 10.5474 1.61929 11.6667 3 11.6667H8C9.38071 11.6667 10.5 10.5474 10.5 9.16666V3.16666C10.5 1.78594 9.38071 0.666656 8 0.666656H3ZM13.684 2.27733L11.5 4.05864V8.2737L13.6842 10.0528C14.0109 10.3188 14.5 10.0864 14.5 9.66511V2.6648C14.5 2.24334 14.0106 2.01095 13.684 2.27733Z" fill="#0078D4"></path></svg></i></span></button></div><div class=""><button type="button" data-testid="heatmap button Sessions with new users" class="ms-Button ms-Button--icon root-104" aria-label="Set as filter and go to heatmaps" data-is-focusable="true"><span class="ms-Button-flexContainer flexContainer-105" data-automationid="splitbuttonprimary"><i data-icon-name="heatmapFilledIn" aria-hidden="true" class="ms-Icon root-89 ms-Button-icon icon-107"><svg width="11" height="14" viewBox="0 0 11 14" fill="none"><path d="M1.11096 5.18914L1.10999 5.19037L1.10825 5.19258L1.10329 5.19894L1.08771 5.21936C1.07491 5.23635 1.05739 5.26009 1.03599 5.29026C0.993205 5.35055 0.934718 5.43679 0.867188 5.54649C0.732399 5.76546 0.559984 6.08054 0.404682 6.47178C0.0947935 7.25245 -0.154773 8.35744 0.123522 9.60856C0.388136 10.7982 0.89831 11.9035 1.78235 12.7126C2.67455 13.5292 3.89967 14 5.50377 14C7.12146 14 8.38791 13.4571 9.24666 12.5266C10.0993 11.6027 10.5038 10.3471 10.5038 9C10.5038 8.14123 10.2183 7.31144 9.83453 6.53604C9.46923 5.7979 8.99516 5.07168 8.54963 4.38919C8.52783 4.35579 8.50609 4.32249 8.48444 4.2893C8.01149 3.56435 7.58091 2.89406 7.29493 2.25635C7.00909 1.61894 6.89723 1.07627 6.99287 0.598058C7.02225 0.45117 6.98422 0.29885 6.88925 0.183006C6.79428 0.0671615 6.65238 0 6.50258 0C6.08062 0 5.37739 0.148379 4.71037 0.493391C4.03729 0.841538 3.33351 1.42606 3.02824 2.34189C2.63813 3.51222 3.08723 4.83198 3.47144 5.66488C3.64247 6.03564 3.49397 6.44529 3.21016 6.5872C2.94287 6.72084 2.61785 6.6125 2.4842 6.34521L1.94979 5.27639C1.87342 5.12365 1.72437 5.02044 1.55452 5.0027C1.38466 4.98497 1.21724 5.05547 1.11096 5.18914Z" fill="#0078D4"></path></svg></i></span></button></div><div class=""><div class="dashboard_legendColor__L+rL3" style="background: rgb(131, 126, 255);"></div></div><div class="dashboard_legendLabel__C-C9u " title="Sessions with returning users">Sessions with returning users</div><div class="">100%</div><div class="">148</div><div class=""><button type="button" data-testid="recording button Sessions with returning users" class="ms-Button ms-Button--icon root-104" aria-label="Set as filter and go to recordings" data-is-focusable="true"><span class="ms-Button-flexContainer flexContainer-105" data-automationid="splitbuttonprimary"><i data-icon-name="cameraFilledIn" aria-hidden="true" class="ms-Icon root-89 ms-Button-icon icon-107"><svg width="15" height="12" viewBox="0 0 15 12" fill="none"><path d="M3 0.666656C1.61929 0.666656 0.5 1.78594 0.5 3.16666V9.16666C0.5 10.5474 1.61929 11.6667 3 11.6667H8C9.38071 11.6667 10.5 10.5474 10.5 9.16666V3.16666C10.5 1.78594 9.38071 0.666656 8 0.666656H3ZM13.684 2.27733L11.5 4.05864V8.2737L13.6842 10.0528C14.0109 10.3188 14.5 10.0864 14.5 9.66511V2.6648C14.5 2.24334 14.0106 2.01095 13.684 2.27733Z" fill="#0078D4"></path></svg></i></span></button></div><div class=""><button type="button" data-testid="heatmap button Sessions with returning users" class="ms-Button ms-Button--icon root-104" aria-label="Set as filter and go to heatmaps" data-is-focusable="true"><span class="ms-Button-flexContainer flexContainer-105" data-automationid="splitbuttonprimary"><i data-icon-name="heatmapFilledIn" aria-hidden="true" class="ms-Icon root-89 ms-Button-icon icon-107"><svg width="11" height="14" viewBox="0 0 11 14" fill="none"><path d="M1.11096 5.18914L1.10999 5.19037L1.10825 5.19258L1.10329 5.19894L1.08771 5.21936C1.07491 5.23635 1.05739 5.26009 1.03599 5.29026C0.993205 5.35055 0.934718 5.43679 0.867188 5.54649C0.732399 5.76546 0.559984 6.08054 0.404682 6.47178C0.0947935 7.25245 -0.154773 8.35744 0.123522 9.60856C0.388136 10.7982 0.89831 11.9035 1.78235 12.7126C2.67455 13.5292 3.89967 14 5.50377 14C7.12146 14 8.38791 13.4571 9.24666 12.5266C10.0993 11.6027 10.5038 10.3471 10.5038 9C10.5038 8.14123 10.2183 7.31144 9.83453 6.53604C9.46923 5.7979 8.99516 5.07168 8.54963 4.38919C8.52783 4.35579 8.50609 4.32249 8.48444 4.2893C8.01149 3.56435 7.58091 2.89406 7.29493 2.25635C7.00909 1.61894 6.89723 1.07627 6.99287 0.598058C7.02225 0.45117 6.98422 0.29885 6.88925 0.183006C6.79428 0.0671615 6.65238 0 6.50258 0C6.08062 0 5.37739 0.148379 4.71037 0.493391C4.03729 0.841538 3.33351 1.42606 3.02824 2.34189C2.63813 3.51222 3.08723 4.83198 3.47144 5.66488C3.64247 6.03564 3.49397 6.44529 3.21016 6.5872C2.94287 6.72084 2.61785 6.6125 2.4842 6.34521L1.94979 5.27639C1.87342 5.12365 1.72437 5.02044 1.55452 5.0027C1.38466 4.98497 1.21724 5.05547 1.11096 5.18914Z" fill="#0078D4"></path></svg></i></span></button></div></div>

# %%
from bs4 import BeautifulSoup

html_content = '<div class="dashboard_legend__Z6dO5"><div class=""><div class="dashboard_legendColor__L+rL3" style="background: rgb(237, 54, 255);"></div></div><div class="dashboard_legendLabel__C-C9u " title="Sessions with new users">Sessions with new users</div><div class="">0%</div><div class="">0</div><div class=""><button type="button" data-testid="recording button Sessions with new users" class="ms-Button ms-Button--icon root-104" aria-label="Set as filter and go to recordings" data-is-focusable="true"><span class="ms-Button-flexContainer flexContainer-105" data-automationid="splitbuttonprimary"><i data-icon-name="cameraFilledIn" aria-hidden="true" class="ms-Icon root-89 ms-Button-icon icon-107"><svg width="15" height="12" viewBox="0 0 15 12" fill="none"><path d="M3 0.666656C1.61929 0.666656 0.5 1.78594 0.5 3.16666V9.16666C0.5 10.5474 1.61929 11.6667 3 11.6667H8C9.38071 11.6667 10.5 10.5474 10.5 9.16666V3.16666C10.5 1.78594 9.38071 0.666656 8 0.666656H3ZM13.684 2.27733L11.5 4.05864V8.2737L13.6842 10.0528C14.0109 10.3188 14.5 10.0864 14.5 9.66511V2.6648C14.5 2.24334 14.0106 2.01095 13.684 2.27733Z" fill="#0078D4"></path></svg></i></span></button></div><div class=""><button type="button" data-testid="heatmap button Sessions with new users" class="ms-Button ms-Button--icon root-104" aria-label="Set as filter and go to heatmaps" data-is-focusable="true"><span class="ms-Button-flexContainer flexContainer-105" data-automationid="splitbuttonprimary"><i data-icon-name="heatmapFilledIn" aria-hidden="true" class="ms-Icon root-89 ms-Button-icon icon-107"><svg width="11" height="14" viewBox="0 0 11 14" fill="none"><path d="M1.11096 5.18914L1.10999 5.19037L1.10825 5.19258L1.10329 5.19894L1.08771 5.21936C1.07491 5.23635 1.05739 5.26009 1.03599 5.29026C0.993205 5.35055 0.934718 5.43679 0.867188 5.54649C0.732399 5.76546 0.559984 6.08054 0.404682 6.47178C0.0947935 7.25245 -0.154773 8.35744 0.123522 9.60856C0.388136 10.7982 0.89831 11.9035 1.78235 12.7126C2.67455 13.5292 3.89967 14 5.50377 14C7.12146 14 8.38791 13.4571 9.24666 12.5266C10.0993 11.6027 10.5038 10.3471 10.5038 9C10.5038 8.14123 10.2183 7.31144 9.83453 6.53604C9.46923 5.7979 8.99516 5.07168 8.54963 4.38919C8.52783 4.35579 8.50609 4.32249 8.48444 4.2893C8.01149 3.56435 7.58091 2.89406 7.29493 2.25635C7.00909 1.61894 6.89723 1.07627 6.99287 0.598058C7.02225 0.45117 6.98422 0.29885 6.88925 0.183006C6.79428 0.0671615 6.65238 0 6.50258 0C6.08062 0 5.37739 0.148379 4.71037 0.493391C4.03729 0.841538 3.33351 1.42606 3.02824 2.34189C2.63813 3.51222 3.08723 4.83198 3.47144 5.66488C3.64247 6.03564 3.49397 6.44529 3.21016 6.5872C2.94287 6.72084 2.61785 6.6125 2.4842 6.34521L1.94979 5.27639C1.87342 5.12365 1.72437 5.02044 1.55452 5.0027C1.38466 4.98497 1.21724 5.05547 1.11096 5.18914Z" fill="#0078D4"></path></svg></i></span></button></div><div class=""><div class="dashboard_legendColor__L+rL3" style="background: rgb(131, 126, 255);"></div></div><div class="dashboard_legendLabel__C-C9u " title="Sessions with returning users">Sessions with returning users</div><div class="">100%</div><div class="">148</div><div class=""><button type="button" data-testid="recording button Sessions with returning users" class="ms-Button ms-Button--icon root-104" aria-label="Set as filter and go to recordings" data-is-focusable="true"><span class="ms-Button-flexContainer flexContainer-105" data-automationid="splitbuttonprimary"><i data-icon-name="cameraFilledIn" aria-hidden="true" class="ms-Icon root-89 ms-Button-icon icon-107"><svg width="15" height="12" viewBox="0 0 15 12" fill="none"><path d="M3 0.666656C1.61929 0.666656 0.5 1.78594 0.5 3.16666V9.16666C0.5 10.5474 1.61929 11.6667 3 11.6667H8C9.38071 11.6667 10.5 10.5474 10.5 9.16666V3.16666C10.5 1.78594 9.38071 0.666656 8 0.666656H3ZM13.684 2.27733L11.5 4.05864V8.2737L13.6842 10.0528C14.0109 10.3188 14.5 10.0864 14.5 9.66511V2.6648C14.5 2.24334 14.0106 2.01095 13.684 2.27733Z" fill="#0078D4"></path></svg></i></span></button></div><div class=""><button type="button" data-testid="heatmap button Sessions with returning users" class="ms-Button ms-Button--icon root-104" aria-label="Set as filter and go to heatmaps" data-is-focusable="true"><span class="ms-Button-flexContainer flexContainer-105" data-automationid="splitbuttonprimary"><i data-icon-name="heatmapFilledIn" aria-hidden="true" class="ms-Icon root-89 ms-Button-icon icon-107"><svg width="11" height="14" viewBox="0 0 11 14" fill="none"><path d="M1.11096 5.18914L1.10999 5.19037L1.10825 5.19258L1.10329 5.19894L1.08771 5.21936C1.07491 5.23635 1.05739 5.26009 1.03599 5.29026C0.993205 5.35055 0.934718 5.43679 0.867188 5.54649C0.732399 5.76546 0.559984 6.08054 0.404682 6.47178C0.0947935 7.25245 -0.154773 8.35744 0.123522 9.60856C0.388136 10.7982 0.89831 11.9035 1.78235 12.7126C2.67455 13.5292 3.89967 14 5.50377 14C7.12146 14 8.38791 13.4571 9.24666 12.5266C10.0993 11.6027 10.5038 10.3471 10.5038 9C10.5038 8.14123 10.2183 7.31144 9.83453 6.53604C9.46923 5.7979 8.99516 5.07168 8.54963 4.38919C8.52783 4.35579 8.50609 4.32249 8.48444 4.2893C8.01149 3.56435 7.58091 2.89406 7.29493 2.25635C7.00909 1.61894 6.89723 1.07627 6.99287 0.598058C7.02225 0.45117 6.98422 0.29885 6.88925 0.183006C6.79428 0.0671615 6.65238 0 6.50258 0C6.08062 0 5.37739 0.148379 4.71037 0.493391C4.03729 0.841538 3.33351 1.42606 3.02824 2.34189C2.63813 3.51222 3.08723 4.83198 3.47144 5.66488C3.64247 6.03564 3.49397 6.44529 3.21016 6.5872C2.94287 6.72084 2.61785 6.6125 2.4842 6.34521L1.94979 5.27639C1.87342 5.12365 1.72437 5.02044 1.55452 5.0027C1.38466 4.98497 1.21724 5.05547 1.11096 5.18914Z" fill="#0078D4"></path></svg></i></span></button></div></div>'

soup = BeautifulSoup(html_content, 'html.parser')

# Extracting the labels and values
labels = soup.find_all('div', class_='dashboard_legendLabel__C-C9u')
values = soup.find_all('div', class_='dashboard_legend__Z6dO5')

for label, value in zip(labels, values):
    label_text = label.text.strip()
    value_text = value.text.strip()

    # Printing the label and value
    #print(label_text)
    print(value_text)
# Out:
# Sessions with new users0%0Sessions with returning users100%148

# %%
<div class="dashboard_topUserRow__rJbzl dashboard_sectionContent__Kmu7w dashboard_userList__gjbC1 dashboard_subtitle__HFgws shared_lightGrayFont__IAlG3"><div class="">9 sessions</div><div class="">Invalid</div><div class=" dashboard_device__0eNh3"><i data-icon-name="laptopFilledIn" aria-hidden="true" class="ms-Icon root-89"><svg width="17" height="11" viewBox="0 0 17 11" fill="none"><path d="M3.33337 0C2.50495 0 1.83337 0.671573 1.83337 1.5V7.5C1.83337 8.32843 2.50495 9 3.33337 9H14.3334C15.1618 9 15.8334 8.32843 15.8334 7.5V1.5C15.8334 0.671573 15.1618 0 14.3334 0H3.33337ZM1.33337 10C1.05723 10 0.833374 10.2239 0.833374 10.5C0.833374 10.7761 1.05723 11 1.33337 11H16.3334C16.6095 11 16.8334 10.7761 16.8334 10.5C16.8334 10.2239 16.6095 10 16.3334 10H1.33337Z" fill="#605E5C"></path></svg></i></div><div class=""><button type="button" data-testid="viewVisitorProfileButton" title="View visitor profile" class="ms-Button ms-Button--icon root-104" aria-label="View visitor profile" data-is-focusable="true"><span class="ms-Button-flexContainer flexContainer-105" data-automationid="splitbuttonprimary"><i data-icon-name="contactCardFilledIn" aria-hidden="true" class="ms-Icon root-89 ms-Button-icon icon-107"><svg width="15" height="10" viewBox="0 0 15 10" fill="none"><path d="M0.5 1.75C0.5 0.783502 1.2835 0 2.25 0H12.75C13.7165 0 14.5 0.783502 14.5 1.75V8.25C14.5 9.2165 13.7165 10 12.75 10H2.25C1.2835 10 0.5 9.2165 0.5 8.25V1.75ZM4.76138 4.71366C5.51074 4.71366 6.11821 4.10619 6.11821 3.35683C6.11821 2.60747 5.51074 2 4.76138 2C4.01203 2 3.40455 2.60747 3.40455 3.35683C3.40455 4.10619 4.01203 4.71366 4.76138 4.71366ZM3.35823 5.39207C2.88424 5.39207 2.5 5.77632 2.5 6.2503C2.5 7.01668 3.02158 7.6847 3.76507 7.87057L3.81845 7.88392C4.43754 8.03869 5.08522 8.03869 5.70432 7.88392L5.7577 7.87057C6.50119 7.6847 7.02277 7.01668 7.02277 6.2503C7.02277 5.77632 6.63852 5.39207 6.16454 5.39207H3.35823ZM9 3C8.72386 3 8.5 3.22386 8.5 3.5C8.5 3.77614 8.72386 4 9 4H12C12.2761 4 12.5 3.77614 12.5 3.5C12.5 3.22386 12.2761 3 12 3H9ZM9 6C8.72386 6 8.5 6.22386 8.5 6.5C8.5 6.77614 8.72386 7 9 7H12C12.2761 7 12.5 6.77614 12.5 6.5C12.5 6.22386 12.2761 6 12 6H9Z" fill="#0078D4"></path></svg></i></span></button></div><div class="dashboard_userListBorder__Z39ia"></div></div>

# %%
from bs4 import BeautifulSoup

html_content = '<div class="dashboard_legend__Z6dO5"><div class=""><div class="dashboard_legendColor__L+rL3" style="background: rgb(237, 54, 255);"></div></div><div class="dashboard_legendLabel__C-C9u " title="Sessions with new users">Sessions with new users</div><div class="">0%</div><div class="">0</div><div class=""><button type="button" data-testid="recording button Sessions with new users" class="ms-Button ms-Button--icon root-104" aria-label="Set as filter and go to recordings" data-is-focusable="true"><span class="ms-Button-flexContainer flexContainer-105" data-automationid="splitbuttonprimary"><i data-icon-name="cameraFilledIn" aria-hidden="true" class="ms-Icon root-89 ms-Button-icon icon-107"><svg width="15" height="12" viewBox="0 0 15 12" fill="none"><path d="M3 0.666656C1.61929 0.666656 0.5 1.78594 0.5 3.16666V9.16666C0.5 10.5474 1.61929 11.6667 3 11.6667H8C9.38071 11.6667 10.5 10.5474 10.5 9.16666V3.16666C10.5 1.78594 9.38071 0.666656 8 0.666656H3ZM13.684 2.27733L11.5 4.05864V8.2737L13.6842 10.0528C14.0109 10.3188 14.5 10.0864 14.5 9.66511V2.6648C14.5 2.24334 14.0106 2.01095 13.684 2.27733Z" fill="#0078D4"></path></svg></i></span></button></div><div class=""><button type="button" data-testid="heatmap button Sessions with new users" class="ms-Button ms-Button--icon root-104" aria-label="Set as filter and go to heatmaps" data-is-focusable="true"><span class="ms-Button-flexContainer flexContainer-105" data-automationid="splitbuttonprimary"><i data-icon-name="heatmapFilledIn" aria-hidden="true" class="ms-Icon root-89 ms-Button-icon icon-107"><svg width="11" height="14" viewBox="0 0 11 14" fill="none"><path d="M1.11096 5.18914L1.10999 5.19037L1.10825 5.19258L1.10329 5.19894L1.08771 5.21936C1.07491 5.23635 1.05739 5.26009 1.03599 5.29026C0.993205 5.35055 0.934718 5.43679 0.867188 5.54649C0.732399 5.76546 0.559984 6.08054 0.404682 6.47178C0.0947935 7.25245 -0.154773 8.35744 0.123522 9.60856C0.388136 10.7982 0.89831 11.9035 1.78235 12.7126C2.67455 13.5292 3.89967 14 5.50377 14C7.12146 14 8.38791 13.4571 9.24666 12.5266C10.0993 11.6027 10.5038 10.3471 10.5038 9C10.5038 8.14123 10.2183 7.31144 9.83453 6.53604C9.46923 5.7979 8.99516 5.07168 8.54963 4.38919C8.52783 4.35579 8.50609 4.32249 8.48444 4.2893C8.01149 3.56435 7.58091 2.89406 7.29493 2.25635C7.00909 1.61894 6.89723 1.07627 6.99287 0.598058C7.02225 0.45117 6.98422 0.29885 6.88925 0.183006C6.79428 0.0671615 6.65238 0 6.50258 0C6.08062 0 5.37739 0.148379 4.71037 0.493391C4.03729 0.841538 3.33351 1.42606 3.02824 2.34189C2.63813 3.51222 3.08723 4.83198 3.47144 5.66488C3.64247 6.03564 3.49397 6.44529 3.21016 6.5872C2.94287 6.72084 2.61785 6.6125 2.4842 6.34521L1.94979 5.27639C1.87342 5.12365 1.72437 5.02044 1.55452 5.0027C1.38466 4.98497 1.21724 5.05547 1.11096 5.18914Z" fill="#0078D4"></path></svg></i></span></button></div><div class=""><div class="dashboard_legendColor__L+rL3" style="background: rgb(131, 126, 255);"></div></div><div class="dashboard_legendLabel__C-C9u " title="Sessions with returning users">Sessions with returning users</div><div class="">100%</div><div class="">148</div><div class=""><button type="button" data-testid="recording button Sessions with returning users" class="ms-Button ms-Button--icon root-104" aria-label="Set as filter and go to recordings" data-is-focusable="true"><span class="ms-Button-flexContainer flexContainer-105" data-automationid="splitbuttonprimary"><i data-icon-name="cameraFilledIn" aria-hidden="true" class="ms-Icon root-89 ms-Button-icon icon-107"><svg width="15" height="12" viewBox="0 0 15 12" fill="none"><path d="M3 0.666656C1.61929 0.666656 0.5 1.78594 0.5 3.16666V9.16666C0.5 10.5474 1.61929 11.6667 3 11.6667H8C9.38071 11.6667 10.5 10.5474 10.5 9.16666V3.16666C10.5 1.78594 9.38071 0.666656 8 0.666656H3ZM13.684 2.27733L11.5 4.05864V8.2737L13.6842 10.0528C14.0109 10.3188 14.5 10.0864 14.5 9.66511V2.6648C14.5 2.24334 14.0106 2.01095 13.684 2.27733Z" fill="#0078D4"></path></svg></i></span></button></div><div class=""><button type="button" data-testid="heatmap button Sessions with returning users" class="ms-Button ms-Button--icon root-104" aria-label="Set as filter and go to heatmaps" data-is-focusable="true"><span class="ms-Button-flexContainer flexContainer-105" data-automationid="splitbuttonprimary"><i data-icon-name="heatmapFilledIn" aria-hidden="true" class="ms-Icon root-89 ms-Button-icon icon-107"><svg width="11" height="14" viewBox="0 0 11 14" fill="none"><path d="M1.11096 5.18914L1.10999 5.19037L1.10825 5.19258L1.10329 5.19894L1.08771 5.21936C1.07491 5.23635 1.05739 5.26009 1.03599 5.29026C0.993205 5.35055 0.934718 5.43679 0.867188 5.54649C0.732399 5.76546 0.559984 6.08054 0.404682 6.47178C0.0947935 7.25245 -0.154773 8.35744 0.123522 9.60856C0.388136 10.7982 0.89831 11.9035 1.78235 12.7126C2.67455 13.5292 3.89967 14 5.50377 14C7.12146 14 8.38791 13.4571 9.24666 12.5266C10.0993 11.6027 10.5038 10.3471 10.5038 9C10.5038 8.14123 10.2183 7.31144 9.83453 6.53604C9.46923 5.7979 8.99516 5.07168 8.54963 4.38919C8.52783 4.35579 8.50609 4.32249 8.48444 4.2893C8.01149 3.56435 7.58091 2.89406 7.29493 2.25635C7.00909 1.61894 6.89723 1.07627 6.99287 0.598058C7.02225 0.45117 6.98422 0.29885 6.88925 0.183006C6.79428 0.0671615 6.65238 0 6.50258 0C6.08062 0 5.37739 0.148379 4.71037 0.493391C4.03729 0.841538 3.33351 1.42606 3.02824 2.34189C2.63813 3.51222 3.08723 4.83198 3.47144 5.66488C3.64247 6.03564 3.49397 6.44529 3.21016 6.5872C2.94287 6.72084 2.61785 6.6125 2.4842 6.34521L1.94979 5.27639C1.87342 5.12365 1.72437 5.02044 1.55452 5.0027C1.38466 4.98497 1.21724 5.05547 1.11096 5.18914Z" fill="#0078D4"></path></svg></i></span></button></div></div>'

soup = BeautifulSoup(html_content, 'html.parser')

# Extracting the labels and values
labels = soup.find_all('div', class_='dashboard_legendLabel__C-C9u')
values = soup.find_all('div', class_='dashboard_legend__Z6dO5')

for label, value in zip(labels, values):
    label_text = label.text.strip()
    value_text = value.text.strip()

    #Printing the label and value
    #print(label_text)
    print(value_text)
# Out:
# Sessions with new users0%0Sessions with returning users100%148

# %%
import requests
from bs4 import BeautifulSoup

url = "https://clarity.microsoft.com/projects/view/m46eh0tli0/dashboard?date=Last%203%20days"

response = requests.get(url)

soup= BeautifulSoup(response.text, 'html')

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
# Extracting title and description
title = soup.find('title').text.strip()
description = soup.find('meta', {'name': 'description'})['content']

# %%
# Creating an HTML report template
html_template = f"""
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>{title}</title>
</head>
<body>
    <h1>{title}</h1>
    <p><strong>Description:</strong> {description}</p>
</body>
</html>
"""

# Save the HTML report to a file
with open('clarity_report.html', 'w', encoding='utf-8') as file:
    file.write(html_template)

print("HTML report generated successfully!")
# Out:
# HTML report generated successfully!

# %%
from bs4 import BeautifulSoup
import requests

# Example HTML content (replace this with your actual HTML content)
html_content = """
<div class="dashboard_tileContent__XVR0e" data-testid="activeDashboardTab">
    <div class="ms-Shimmer-container dashboard_userCardShimmerContainer__GHdUi root-257">
        <div class="ms-Shimmer-dataWrapper dataWrapper-344">
            <div class="dashboard_usersData__K8-tI">
                <div class="dashboard_usersNumber__0oR2P dashboard_loud__ynA6u shared_darkBlueFont__owkq3">2</div>
                <div class="dashboard_usersNumber__0oR2P dashboard_loud__ynA6u shared_darkBlueFont__owkq3" data-testid="distinctUsers">25</div>
            </div>
        </div>
    </div>
</div>
"""

# Parse HTML
soup = BeautifulSoup(html_content, 'html.parser')

# Example: Extracting number of live users
live_users = soup.find('div', class_='dashboard_usersNumber__0oR2P dashboard_loud__ynA6u shared_darkBlueFont__owkq3')
if live_users:
    live_users_count = live_users.text.strip()
    print(f"Live users: {live_users_count}")

# Example: Extracting number of unique users
unique_users = soup.find('div', class_='dashboard_usersNumber__0oR2P dashboard_loud__ynA6u shared_darkBlueFont__owkq3', attrs={'data-testid': 'distinctUsers'})
if unique_users:
    unique_users_count = unique_users.text.strip()
    print(f"Unique users: {unique_users_count}")
# Out:
# Live users: 2
# Unique users: 25

# %%
html_content = f"""
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Dashboard Report</title>
    <style>
        /* Add your custom styles here */
        body {{
            font-family: Arial, sans-serif;
            line-height: 1.6;
            margin: 20px;
            padding: 0;
        }}
        .dashboard {{
            display: grid;
            grid-template-columns: 1fr 1fr;
            gap: 20px;
        }}
        .dashboard_tileContent__XVR0e {{
            background: #f0f0f0;
            padding: 20px;
            border-radius: 8px;
        }}
        /* Add more styles as needed */
    </style>
</head>
<body>
    <div class="dashboard">
        <!-- Insert your HTML content here -->
        <div class="dashboard_tileContent__XVR0e">
            <!-- Replace with your actual dashboard content -->
            <!-- Example: Live Users -->
            <div class="ms-Shimmer-container dashboard_userCardShimmerContainer__GHdUi root-257">
                <!-- Shimmer effect or loading indicator -->
                <!-- Replace with actual content -->
                <div class="dashboard_usersData__K8-tI">
                    <div class="dashboard_usersIcon__ivfmJ">
                        <!-- Icon or SVG -->
                    </div>
                    <div class="dashboard_usersNumber__0oR2P dashboard_loud__ynA6u shared_darkBlueFont__owkq3">2</div>
                    <div class="dashboard_usersInfoLabel__1fFNK dashboard_label__6chaC shared_darkGrayFontBold__bK3Bp shared_verticalFlex__rAS0M shared_flex__bW95Y">
                        <div>Live users</div>
                        <div class="dashboard_usersInfoSubtitle__DiYOz dashboard_italicSubtitle__c4hmJ dashboard_subtitle__HFgws shared_lightGrayFont__IAlG3">1.0 min ago</div>
                    </div>
                    <div class="dashboard_usersRecording__uUJ+x">
                        <button type="button" class="ms-Button ms-Button--icon root-104" aria-label="Set as filter and go to recordings" data-is-focusable="true">
                            <!-- Recording button -->
                            <span class="ms-Button-flexContainer flexContainer-105" data-automationid="splitbuttonprimary">
                                <i data-icon-name="cameraFilledIn" aria-hidden="true" class="ms-Icon root-89 ms-Button-icon icon-107">
                                    <!-- SVG icon -->
                                    <svg width="15" height="12" viewBox="0 0 15 12" fill="none">
                                        <path d="M3 0.666656C1.61929 0.666656 0.5 1.78594 0.5 3.16666V9.16666C0.5 10.5474 1.61929 11.6667 3 11.6667H8C9.38071 11.6667 10.5 10.5474 10.5 9.16666V3.16666C10.5 1.78594 9.38071 0.666656 8 0.666656H3ZM13.684 2.27733L11.5 4.05864V8.2737L13.6842 10.0528C14.0109 10.3188 14.5 10.0864 14.5 9.66511V2.6648C14.5 2.24334 14.0106 2.01095 13.684 2.27733Z" fill="#0078D4"></path>
                                    </svg>
                                </i>
                            </span>
                        </button>
                    </div>
                    <!-- Add more content as needed -->
                </div>
            </div>
            <!-- Repeat similar structure for other dashboard tiles -->
        </div>
        <!-- Add more dashboard tiles if necessary -->
    </div>
</body>
</html>
"""


# Save the HTML content to a file
with open('output.html', 'w') as html_file:
    html_file.write(html_content)

print("HTML file 'output.html' has been created.")
# Out:
# HTML file 'output.html' has been created.

# %%
# !pip install selenium
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   WARNING: The script wsdump.exe is installed in 'C:\Users\akshaya\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# jupyter-server 1.13.5 requires pywinpty<2; os_name == "nt", but you have pywinpty 2.0.2 which is incompatible.
